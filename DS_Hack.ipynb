# %%
import pandas as pd
import re
import pymorphy2
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')

# %%
import nltk
nltk.download('vader_lexicon')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#df = df.loc[(df['1category'] != '?') & (df['2category'].isna())]

# %%
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
result = " ".join(df.where(df['sentiment'] == "+").dropna(how = 'all')['sentence'])

from collections import Counter

words = re.findall(r'\b\w+\b', result.lower())
words = [word for word in words if word not in stopwords]
words = [morph.parse(word)[0].normal_form for word in words]
good = Counter(words)


result = " ".join(df.where(df['sentiment'] == "−").dropna(how = 'all')['sentence'])
words = re.findall(r'\b\w+\b', result.lower())
words = [word for word in words if word not in stopwords]
words = [morph.parse(word)[0].normal_form for word in words]
bad = Counter(words)

bad = bad.most_common(100)


good = good.most_common(100)

good_list = []
bad_list = []
for i in range(100):
    good_list.append(good[i][0])
    bad_list.append(bad[i][0])


# Преобразование списков в множества
set1 = set(good_list)
set2 = set(bad_list)

# Получение уникальных элементов каждого множества
unique_set1 = set1.difference(set2)
unique_set2 = set2.difference(set1)

# Преобразование множеств обратно в списки
only_good = list(unique_set1)
only_bad = list(unique_set2)

print(only_good) 
print(only_bad)
# Out:
# ['уровень', 'помощь', 'выразить', 'объяснить', 'профессионализм', 'довольный', 'общение', 'грамотный', 'оперативность', 'тинькофф', 'удобный', 'огромный', 'положительный', 'быстро', 'вклад', 'приятно', 'отличный', 'помочь', 'высокий', 'рекомендовать', 'вежливый', 'ответить', 'оперативно', 'отметить', 'подробно', 'условие', 'спасибо', 'понравиться', 'плюс', 'благодарность', 'решение', 'всё', 'приятный', 'продукт', 'приложение', 'наш', 'удобно', 'девушка', 'также', 'дело', 'профессиональный', 'впечатление', 'хороший', 'платёж', 'большой', 'любой', 'интернет', 'рассказать']
# ['1', 'считать', 'обращение', 'срок', 'писать', '3', '2', 'говорить', 'деньга', 'оператор', 'один', 'должный', 'крайне', 'некомпетентный', 'звонить', 'информация', 'отвратительный', 'линия', 'абсолютно', 'звонок', 'советовать', 'месяц', 'знать', 'никто', 'сумма', 'заявление', 'позвонить', 'ужасный', 'сегодня', 'вообще', 'написать', 'заявка', 'ещё', 'горячий', 'договор', 'банкомат', 'полный', 'ответ', 'никакой', 'ситуация', 'какой', 'итог', 'номер', 'делать', 'невозможно', 'центр', 'почему', 'средство']

# %%
df['num_digits'] = df['sentence'].str.count(r'\d')

# Функция, которая проверяет наличие даты в формате xx.xx.xxxx в строке
def has_date(date_string):
    patterns = [
        r'\b\d{2}\.\d{2}\.\d{4}\b',    # Формат xx.xx.xxxx
        r'\b\d{2}[-/]\d{2}[-/]\d{2}\b', # Формат xx-xx-xx или xx/xx/xx
        # Дополнительные паттерны, включая варианты с названиями месяцев на русском языке
        r'\b\d{1,2} [Яя]нвар[яь] \d{4}\b',
        r'\b\d{1,2} [Фф]еврал[яь] \d{4}\b',
        r'\b\d{1,2} [Мм]арт[а] \d{4}\b',
        r'\b\d{1,2} [Аа]прел[яь] \d{4}\b',
        r'\b\d{1,2} [Мм]а[яй] \d{4}\b',
        r'\b\d{1,2} [Ии]юн[яь] \d{4}\b',
        r'\b\d{1,2} [Ии]юл[яь] \d{4}\b',
        r'\b\d{1,2} [Аа]вгуст[а] \d{4}\b',
        r'\b\d{1,2} [Сс]ентябр[яь] \d{4}\b',
        r'\b\d{1,2} [Оо]ктябр[яь] \d{4}\b',
        r'\b\d{1,2} [Нн]оябр[яь] \d{4}\b',
        r'\b\d{1,2} [Дд]екабр[яь] \d{4}\b',
    ]
    for pattern in patterns:
        match = re.search(pattern, date_string)
        if match:
            return 1
    return 0
df['has_date'] = df['sentence'].apply(has_date)

# Функция, которая проверяет наличие даты в формате xx.xx.xxxx в строке
def has_ad(date_string):
    address_patterns = [r'([А-ЯЁ][а-яё]+(?:-+[А-ЯЁ][а-яё]+)*(?: [0-9]+[а-яё]*)(?:/[0-9]+)*)',
                        r'([А-ЯЁ][а-яё]+(?:-+[А-ЯЁ][а-яё]+)*)[, ]+([А-ЯЁ][а-яё]+(?:-+[А-ЯЁ][а-яё]+)*(?: [0-9]+[а-яё]*)(?:/[0-9]+)*)'
                        ,r'([А-ЯЁ][а-яё]+(?:-+[А-ЯЁ][а-яё]+)*(?: [0-9]+[а-яё]*)(?:/[0-9]+)*)(?:,| в)+([А-ЯЁ][а-яё]+(?:-+[А-ЯЁ][а-яё]+)*)']
    for pattern in address_patterns:
        match = re.search(pattern, date_string)
        if match is not None:
            return 1
    return 0

# Добавляем новый столбец 'has_ad'
df['has_ad'] = df['sentence'].apply(has_ad)

def has_phone_number (date_string):
    patterns = [
    r"\+7\d{10}",
    r"8\d{10}",
    r"8\s?\d{3}\s?\d{3}-?\d{2}-?\d{2}",
    r"\d{11}"
    ]
    for pattern in patterns:
        match = re.search(pattern, date_string)
        if match is not None:
            return 1
    return 0
df['has_phone_number'] = df['sentence'].apply(has_phone_number)

def len_review (date_string):
    return len(date_string)
df['len_review'] = df['sentence'].apply(len_review)

def warning_sign1(date_string):
    if '!' in date_string:
        return 1
    else: 
        return 0
df['warning_sign1'] = df['sentence'].apply(warning_sign1)    

def count_warning_signs(s):
    return s.count("!")
df['count_warning_signs'] = df['sentence'].apply(count_warning_signs)

def caps_words_count(df):
    caps_words_count = []
    for sentence in df['sentence']:
        caps_words = [word for word in sentence.split() if word.isupper()]
        caps_words_count.append(len(caps_words))
    df['caps_words_count'] = caps_words_count
    return df
df = caps_words_count(df)

def get_bracket_value(text):
    count_open = text.count("(")
    count_close = text.count(")")
    if count_open > count_close:
        return 1
    elif count_open < count_close:
        return 2
    else:
        return 0
df['brackets'] = df['sentence'].apply(get_bracket_value)

def has_english_letters(s):
    """
    Функция принимает строку s и возвращает 1, если в ней есть английские буквы,
    и возвращает 0 в противном случае.
    """
    for char in s:
        if char.isalpha() and char.isascii():
            # Проверяем, является ли символ буквой и английским символом 
            return 1
    return 0
df['has_english_letters'] = df['sentence'].apply(has_english_letters)

def count_answer_sign(s):
    return s.count("!")
df['count_answer_sign'] = df['sentence'].apply(count_answer_sign)

def count_dots(s):
    return s.count(".")
df['count_dots'] = df['sentence'].apply(count_dots)

def count_minus(s):
    return s.count("-")
df['count_minus'] = df['sentence'].apply(count_minus)

def count_minus(s):
    return s.count("-")
df['count_minus'] = df['sentence'].apply(count_minus)

def count_plus(s):
    return s.count("+")
df['count_plus'] = df['sentence'].apply(count_plus)

def гub(date_string):
    if 'руб' in date_string or 'тыс' in date_string:
        return 1
    else: 
        return 0
df['гub'] = df['sentence'].apply(гub)

# %%
def mood(df):
    good_words_count = []
    bad_words_count = []
    words = re.findall(r'\b\w+\b', result.lower())
    words = [word for word in words if word not in stopwords]
    words = [morph.parse(word)[0].normal_form for word in words]
    for sentence in df['sentence']:
        words = re.findall(r'\b\w+\b', sentence.lower())
        words = [word for word in words if word not in stopwords]
        words = [morph.parse(word)[0].normal_form for word in words]
        good_counts = {word: words.count(word) for word in only_good}
        bad_counts = {word: words.count(word) for word in only_bad}
        good_words_count.append(good_counts)
        bad_words_count.append(bad_counts)
    df['good_words'] = good_words_count
    df['bad_words'] = bad_words_count
    return df
df = mood(df)

# %%
df['good_c'] = 0
df['bad_c'] = 0
for i in range(len(df.index)):
    
    df['good_c'][df.index[i]] = sum(df['good_words'][df.index[i]].values())
    df['bad_c'][df.index[i]] = sum(df['bad_words'][df.index[i]].values())
# Out:
# <ipython-input-8-88568bb7e1f3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['good_c'][df.index[i]] = sum(df['good_words'][df.index[i]].values())
# <ipython-input-8-88568bb7e1f3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bad_c'][df.index[i]] = sum(df['bad_words'][df.index[i]].values())

# %%
banks=['Сбербанк','ВТБ','Альфа','Тинькофф','Сити','Россельхозбанк','Росбанк','Райф','МТС','ИКС','Уралсиб','Банк России','Банк Открытие'] 
import spacy
import numpy as np
nlp=spacy.blank('ru')

def find_bank_names(docs):
    bank_names = []
    for doc in docs:
        found = False
        for token in doc:
            if token.text in banks:
                found = True
                bank_names.append(token.text)
                break
        if not found:
            bank_names.append(None)
    return bank_names

def mark_bank_name(df):
    docs = list(nlp.pipe(df['sentence']))
    df['bank_name'] = find_bank_names(docs) 
    return df 
df=mark_bank_name(df)
groupby_bank = df.groupby('bank_name')[['1category', '2category','sentiment']].agg(lambda x: x.mode().iloc[0]).reset_index()
merged = pd.merge(df, groupby_bank, on='bank_name', how='left')
for bank in banks:
    col_name = f"{bank}_1category_mode"
    merged[col_name] = merged['1category_y'].where(merged['bank_name'] == bank, np.nan)
    col_name = f"{bank}_2category_mode"
    merged[col_name] = merged['2category_y'].where(merged['bank_name'] == bank, np.nan)
    col_name = f"{bank}_sentiment_mode"
    merged[col_name] = merged['sentiment_y'].where(merged['bank_name'] == bank, np.nan)
merged=merged.drop(columns=(['1category_y','2category_y','sentiment_y']))

# %%
bank_map = {bank_name: i for i, bank_name in enumerate(banks)}
df['bank_name'] = df['bank_name'].map(bank_map)
df['bank_name'].fillna(0, inplace= True)

# %%
df['bank_name'].unique()

# %%
df

# %%
from sklearn import tree
import matplotlib.pyplot as plt


from IPython.display import SVG
from graphviz import Source
from IPython.display import display

import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import mean_squared_error,r2_score 

import warnings
warnings.filterwarnings('ignore')
breast_cancer = load_breast_cancer()

import pandas as pd
import numpy as np
import re
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve
from sklearn.feature_selection import SelectFromModel, SelectKBest
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, confusion_matrix, precision_score, recall_score

pd.options.display.max_columns = 100

# %%
x = df.drop(columns= ['Unnamed: 0', 'sentence', '1category', '2category', 'sentiment', 'good_words', 'bad_words' ])
y = pd.DataFrame(df['sentiment'])
y['sentiment'] = y['sentiment'].replace({'+': 1, '−': 0, '?': 2})
y = y.astype(float)

# %%
#!c1.32
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split


# Разделение данных на тренировочный и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(x, y.values.ravel(), test_size=0.1)

# Создание объекта классификатора RandomForestClassifier
clf = RandomForestClassifier()

# Определение сетки гиперпараметров для GridSearchCV
param_grid = {'n_estimators': [250],
              'max_depth': [20, 30]}

# Создание объекта GridSearchCV
grid_search = GridSearchCV(clf, param_grid=param_grid, cv=10, scoring='roc_auc_ovr')

# Обучение классификатора с использованием GridSearchCV
grid_search.fit(X_train, y_train)

# Вычисление ROC AUC для многоклассовой классификации с методом OvR
y_pred_proba = grid_search.predict_proba(X_test)
roc_auc_ovr = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
#train_score = clf.score(X_train, y_train)
#test_score = clf.score(X_test, y_test)
#mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv = 10).mean()
#temp_score_data = pd.DataFrame({"max_depth": [max_depth], "train_score" : [train_score], "test_score": [test_score], "mean_cross_val_score": [mean_cross_val_score]})
#scores_data = scores_data.append(temp_score_data)
# Вывод результатов
print("Best parameters:", grid_search.best_params_)
print("ROC AUC (OvR):", roc_auc_ovr)
# Out:
# Best parameters: {'max_depth': 30, 'n_estimators': 250}
# ROC AUC (OvR): 0.9017491023947439

# %%
scores_data_long = pd.melt(scores_data, id_vars = ["max_depth"], value_vars = ["train_score", "test_score", "mean_cross_val_score"], var_name = "set_type", value_name= "score")
sns.lineplot(x = "max_depth", y = "score", hue = "set_type", data = scores_data_long )

# %%
from catboost import CatBoostClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
from catboost import CatBoostClassifier

# Создание классификатора
clf = CatBoostClassifier(eval_metric='MultiClass')

# Обучение классификатора
clf.fit(X_train, y_train)

# Предсказание на тестовых данных
y_pred = clf.predict(X_test)

# Вычисление ROC AUC
from sklearn.metrics import roc_auc_score

roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test), multi_class='ovr')
print('ROC AUC:', roc_auc)

# %%
from sklearn.model_selection import GridSearchCV

# Определение параметров для подбора
params = {
    'iterations': [100, 500, 1000],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [10,16]
}

# Создание объекта классификатора
clf = CatBoostClassifier(loss_function='MultiClass')

# Создание объекта GridSearchCV
grid_search = GridSearchCV(clf, params, cv=5, scoring='roc_auc_ovr')

# Обучение классификатора с перебором параметров
grid_search.fit(X_train, y_train)

# Определение лучших параметров
best_params = grid_search.best_params_
print('Лучшие параметры:', best_params)

# Оценка качества модели с лучшими параметрами на тестовой выборке
clf_best = CatBoostClassifier(**best_params, loss_function='MultiClass', eval_metric='MultiClassOneVsAll', random_seed=42)
clf_best.fit(X_train, y_train)
y_pred = clf_best.predict(X_test)
roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr')
print('ROC AUC (One vs Rest):', roc_auc)
# Out:
# 0:	learn: 1.0919148	total: 105ms	remaining: 10.4s
# 1:	learn: 1.0856356	total: 126ms	remaining: 6.18s
# 2:	learn: 1.0794835	total: 134ms	remaining: 4.32s
# 3:	learn: 1.0733048	total: 151ms	remaining: 3.62s
# 4:	learn: 1.0672526	total: 168ms	remaining: 3.19s
# 5:	learn: 1.0613161	total: 185ms	remaining: 2.9s
# 6:	learn: 1.0554837	total: 202ms	remaining: 2.69s
# 7:	learn: 1.0498051	total: 213ms	remaining: 2.45s
# 8:	learn: 1.0444118	total: 233ms	remaining: 2.35s
# 9:	learn: 1.0389104	total: 251ms	remaining: 2.26s
# 10:	learn: 1.0336334	total: 268ms	remaining: 2.17s
# 11:	learn: 1.0284659	total: 294ms	remaining: 2.15s
# 12:	learn: 1.0233889	total: 303ms	remaining: 2.03s
# 13:	learn: 1.0183818	total: 332ms	remaining: 2.04s
# 14:	learn: 1.0134309	total: 349ms	remaining: 1.98s
# 15:	learn: 1.0086443	total: 365ms	remaining: 1.92s
# 16:	learn: 1.0040088	total: 383ms	remaining: 1.87s
# 17:	learn: 0.9994710	total: 401ms	remaining: 1.83s
# 18:	learn: 0.9950385	total: 420ms	remaining: 1.79s
# 19:	learn: 0.9905759	total: 439ms	remaining: 1.75s
# 20:	learn: 0.9863323	total: 459ms	remaining: 1.73s
# 21:	learn: 0.9822272	total: 478ms	remaining: 1.69s
# 22:	learn: 0.9780419	total: 501ms	remaining: 1.68s
# 23:	learn: 0.9740898	total: 519ms	remaining: 1.64s
# 24:	learn: 0.9700947	total: 540ms	remaining: 1.62s
# 25:	learn: 0.9660820	total: 560ms	remaining: 1.59s
# 26:	learn: 0.9623497	total: 578ms	remaining: 1.56s
# 27:	learn: 0.9585369	total: 595ms	remaining: 1.53s
# 28:	learn: 0.9549262	total: 613ms	remaining: 1.5s
# 29:	learn: 0.9512902	total: 630ms	remaining: 1.47s
# 30:	learn: 0.9477263	total: 648ms	remaining: 1.44s
# 31:	learn: 0.9442001	total: 665ms	remaining: 1.41s
# 32:	learn: 0.9408715	total: 673ms	remaining: 1.37s
# 33:	learn: 0.9374184	total: 695ms	remaining: 1.35s
# 34:	learn: 0.9340624	total: 719ms	remaining: 1.33s
# 35:	learn: 0.9307097	total: 737ms	remaining: 1.31s
# 36:	learn: 0.9275680	total: 764ms	remaining: 1.3s
# 37:	learn: 0.9244378	total: 781ms	remaining: 1.27s
# 38:	learn: 0.9213690	total: 799ms	remaining: 1.25s
# 39:	learn: 0.9182654	total: 816ms	remaining: 1.22s
# 40:	learn: 0.9152240	total: 834ms	remaining: 1.2s
# 41:	learn: 0.9122122	total: 852ms	remaining: 1.18s
# 42:	learn: 0.9092940	total: 869ms	remaining: 1.15s
# 43:	learn: 0.9064287	total: 895ms	remaining: 1.14s
# 44:	learn: 0.9036287	total: 912ms	remaining: 1.11s
# 45:	learn: 0.9010280	total: 927ms	remaining: 1.09s
# 46:	learn: 0.8982462	total: 945ms	remaining: 1.06s
# 47:	learn: 0.8955097	total: 962ms	remaining: 1.04s
# 48:	learn: 0.8928598	total: 980ms	remaining: 1.02s
# 49:	learn: 0.8903143	total: 998ms	remaining: 998ms
# 50:	learn: 0.8878242	total: 1.01s	remaining: 976ms
# 51:	learn: 0.8852862	total: 1.03s	remaining: 955ms
# 52:	learn: 0.8829723	total: 1.05s	remaining: 933ms
# 53:	learn: 0.8807222	total: 1.07s	remaining: 912ms
# 54:	learn: 0.8784036	total: 1.09s	remaining: 895ms
# 55:	learn: 0.8761221	total: 1.11s	remaining: 874ms
# 56:	learn: 0.8738326	total: 1.14s	remaining: 857ms
# 57:	learn: 0.8715800	total: 1.15s	remaining: 835ms
# 58:	learn: 0.8694261	total: 1.18s	remaining: 819ms
# 59:	learn: 0.8672215	total: 1.2s	remaining: 798ms
# 60:	learn: 0.8651715	total: 1.21s	remaining: 777ms
# 61:	learn: 0.8630730	total: 1.23s	remaining: 755ms
# 62:	learn: 0.8609111	total: 1.25s	remaining: 734ms
# 63:	learn: 0.8588407	total: 1.27s	remaining: 713ms
# 64:	learn: 0.8569380	total: 1.29s	remaining: 695ms
# 65:	learn: 0.8549425	total: 1.31s	remaining: 677ms
# 66:	learn: 0.8531095	total: 1.33s	remaining: 656ms
# 67:	learn: 0.8511672	total: 1.35s	remaining: 637ms
# 68:	learn: 0.8493907	total: 1.37s	remaining: 616ms
# 69:	learn: 0.8474295	total: 1.39s	remaining: 597ms
# 70:	learn: 0.8455943	total: 1.41s	remaining: 576ms
# 71:	learn: 0.8438317	total: 1.43s	remaining: 555ms
# 72:	learn: 0.8421465	total: 1.45s	remaining: 534ms
# 73:	learn: 0.8403707	total: 1.46s	remaining: 514ms
# 74:	learn: 0.8386984	total: 1.49s	remaining: 498ms
# 75:	learn: 0.8371675	total: 1.52s	remaining: 479ms
# 76:	learn: 0.8355133	total: 1.54s	remaining: 459ms
# 77:	learn: 0.8338631	total: 1.56s	remaining: 439ms
# 78:	learn: 0.8321676	total: 1.57s	remaining: 419ms
# 79:	learn: 0.8306506	total: 1.59s	remaining: 399ms
# 80:	learn: 0.8291943	total: 1.61s	remaining: 379ms
# 81:	learn: 0.8276203	total: 1.63s	remaining: 358ms
# 82:	learn: 0.8260814	total: 1.65s	remaining: 338ms
# 83:	learn: 0.8247278	total: 1.67s	remaining: 318ms
# 84:	learn: 0.8233444	total: 1.7s	remaining: 300ms
# 85:	learn: 0.8221107	total: 1.72s	remaining: 280ms
# 86:	learn: 0.8207077	total: 1.74s	remaining: 260ms
# 87:	learn: 0.8192980	total: 1.76s	remaining: 241ms
# 88:	learn: 0.8178297	total: 1.78s	remaining: 220ms
# 89:	learn: 0.8165168	total: 1.8s	remaining: 200ms
# 90:	learn: 0.8152147	total: 1.82s	remaining: 180ms
# 91:	learn: 0.8137664	total: 1.84s	remaining: 160ms
# 92:	learn: 0.8123521	total: 1.86s	remaining: 140ms
# 93:	learn: 0.8110873	total: 1.88s	remaining: 120ms
# 94:	learn: 0.8098635	total: 1.9s	remaining: 99.8ms
# 95:	learn: 0.8085378	total: 1.92s	remaining: 79.8ms
# 96:	learn: 0.8072785	total: 1.94s	remaining: 59.9ms
# 97:	learn: 0.8061442	total: 1.95s	remaining: 39.8ms
# 98:	learn: 0.8048707	total: 1.97s	remaining: 19.9ms
# 99:	learn: 0.8038772	total: 1.99s	remaining: 0us
# 0:	learn: 1.0918044	total: 18.7ms	remaining: 1.85s
# 1:	learn: 1.0854133	total: 40.1ms	remaining: 1.97s
# 2:	learn: 1.0789638	total: 58ms	remaining: 1.88s
# 3:	learn: 1.0727772	total: 85.4ms	remaining: 2.05s
# 4:	learn: 1.0665567	total: 103ms	remaining: 1.95s
# 5:	learn: 1.0605108	total: 123ms	remaining: 1.93s
# 6:	learn: 1.0546308	total: 145ms	remaining: 1.93s
# 7:	learn: 1.0490223	total: 166ms	remaining: 1.91s
# 8:	learn: 1.0433134	total: 183ms	remaining: 1.85s
# 9:	learn: 1.0377043	total: 201ms	remaining: 1.81s
# 10:	learn: 1.0324731	total: 224ms	remaining: 1.81s
# 11:	learn: 1.0271725	total: 244ms	remaining: 1.79s
# 12:	learn: 1.0221397	total: 263ms	remaining: 1.76s
# 13:	learn: 1.0171163	total: 280ms	remaining: 1.72s
# 14:	learn: 1.0121778	total: 306ms	remaining: 1.73s
# 15:	learn: 1.0072973	total: 326ms	remaining: 1.71s
# 16:	learn: 1.0024573	total: 349ms	remaining: 1.7s
# 17:	learn: 0.9977172	total: 368ms	remaining: 1.68s
# 18:	learn: 0.9931319	total: 385ms	remaining: 1.64s
# 19:	learn: 0.9885466	total: 404ms	remaining: 1.62s
# 20:	learn: 0.9841315	total: 431ms	remaining: 1.62s
# 21:	learn: 0.9798145	total: 454ms	remaining: 1.61s
# 22:	learn: 0.9757915	total: 479ms	remaining: 1.6s
# 23:	learn: 0.9716094	total: 496ms	remaining: 1.57s
# 24:	learn: 0.9675270	total: 517ms	remaining: 1.55s
# 25:	learn: 0.9633935	total: 538ms	remaining: 1.53s
# 26:	learn: 0.9594422	total: 555ms	remaining: 1.5s
# 27:	learn: 0.9555729	total: 573ms	remaining: 1.47s
# 28:	learn: 0.9519734	total: 591ms	remaining: 1.45s
# 29:	learn: 0.9484012	total: 613ms	remaining: 1.43s
# 30:	learn: 0.9448461	total: 638ms	remaining: 1.42s
# 31:	learn: 0.9415467	total: 649ms	remaining: 1.38s
# 32:	learn: 0.9380592	total: 669ms	remaining: 1.36s
# 33:	learn: 0.9346612	total: 687ms	remaining: 1.33s
# 34:	learn: 0.9311970	total: 704ms	remaining: 1.31s
# 35:	learn: 0.9278912	total: 724ms	remaining: 1.29s
# 36:	learn: 0.9245072	total: 745ms	remaining: 1.27s
# 37:	learn: 0.9212552	total: 765ms	remaining: 1.25s
# 38:	learn: 0.9180760	total: 783ms	remaining: 1.23s
# 39:	learn: 0.9149462	total: 802ms	remaining: 1.2s
# 40:	learn: 0.9118998	total: 824ms	remaining: 1.19s
# 41:	learn: 0.9090663	total: 846ms	remaining: 1.17s
# 42:	learn: 0.9062215	total: 866ms	remaining: 1.15s
# 43:	learn: 0.9032352	total: 888ms	remaining: 1.13s
# 44:	learn: 0.9004154	total: 905ms	remaining: 1.11s
# 45:	learn: 0.8976654	total: 926ms	remaining: 1.09s
# 46:	learn: 0.8949122	total: 948ms	remaining: 1.07s
# 47:	learn: 0.8921779	total: 969ms	remaining: 1.05s
# 48:	learn: 0.8895695	total: 988ms	remaining: 1.03s
# 49:	learn: 0.8870225	total: 1.01s	remaining: 1.01s
# 50:	learn: 0.8844128	total: 1.03s	remaining: 994ms
# 51:	learn: 0.8819276	total: 1.06s	remaining: 979ms
# 52:	learn: 0.8795270	total: 1.08s	remaining: 958ms
# 53:	learn: 0.8770787	total: 1.1s	remaining: 940ms
# 54:	learn: 0.8747427	total: 1.12s	remaining: 917ms
# 55:	learn: 0.8723801	total: 1.14s	remaining: 899ms
# 56:	learn: 0.8700137	total: 1.17s	remaining: 879ms
# 57:	learn: 0.8676630	total: 1.18s	remaining: 857ms
# 58:	learn: 0.8654801	total: 1.2s	remaining: 836ms
# 59:	learn: 0.8632767	total: 1.23s	remaining: 819ms
# 60:	learn: 0.8611095	total: 1.25s	remaining: 800ms
# 61:	learn: 0.8591492	total: 1.27s	remaining: 781ms
# 62:	learn: 0.8569318	total: 1.29s	remaining: 760ms
# 63:	learn: 0.8549098	total: 1.32s	remaining: 742ms
# 64:	learn: 0.8530006	total: 1.34s	remaining: 720ms
# 65:	learn: 0.8509853	total: 1.36s	remaining: 700ms
# 66:	learn: 0.8490230	total: 1.38s	remaining: 680ms
# 67:	learn: 0.8470732	total: 1.4s	remaining: 660ms
# 68:	learn: 0.8452328	total: 1.42s	remaining: 639ms
# 69:	learn: 0.8434204	total: 1.44s	remaining: 619ms
# 70:	learn: 0.8415792	total: 1.47s	remaining: 599ms
# 71:	learn: 0.8396144	total: 1.49s	remaining: 579ms
# 72:	learn: 0.8377743	total: 1.51s	remaining: 559ms
# 73:	learn: 0.8360027	total: 1.53s	remaining: 539ms
# 74:	learn: 0.8343804	total: 1.55s	remaining: 517ms
# 75:	learn: 0.8326502	total: 1.57s	remaining: 497ms
# 76:	learn: 0.8309611	total: 1.59s	remaining: 476ms
# 77:	learn: 0.8293415	total: 1.62s	remaining: 456ms
# 78:	learn: 0.8276382	total: 1.63s	remaining: 435ms
# 79:	learn: 0.8260310	total: 1.66s	remaining: 414ms
# 80:	learn: 0.8244459	total: 1.68s	remaining: 394ms
# 81:	learn: 0.8229295	total: 1.7s	remaining: 374ms
# 82:	learn: 0.8214071	total: 1.72s	remaining: 352ms
# 83:	learn: 0.8199380	total: 1.74s	remaining: 332ms
# 84:	learn: 0.8185398	total: 1.75s	remaining: 309ms
# 85:	learn: 0.8170821	total: 1.78s	remaining: 289ms
# 86:	learn: 0.8155004	total: 1.8s	remaining: 269ms
# 87:	learn: 0.8140950	total: 1.82s	remaining: 249ms
# 88:	learn: 0.8125188	total: 1.84s	remaining: 228ms
# 89:	learn: 0.8112887	total: 1.85s	remaining: 206ms
# 90:	learn: 0.8099104	total: 1.88s	remaining: 186ms
# 91:	learn: 0.8086808	total: 1.9s	remaining: 165ms
# 92:	learn: 0.8074531	total: 1.92s	remaining: 144ms
# 93:	learn: 0.8060440	total: 1.94s	remaining: 124ms
# 94:	learn: 0.8047558	total: 1.96s	remaining: 103ms
# 95:	learn: 0.8034788	total: 1.98s	remaining: 82.5ms
# 96:	learn: 0.8021181	total: 2s	remaining: 61.9ms
# 97:	learn: 0.8009702	total: 2.02s	remaining: 41.2ms
# 98:	learn: 0.7997964	total: 2.04s	remaining: 20.6ms
# 99:	learn: 0.7984711	total: 2.06s	remaining: 0us
# 0:	learn: 1.0918352	total: 19.5ms	remaining: 1.93s
# 1:	learn: 1.0853227	total: 38.4ms	remaining: 1.88s
# 2:	learn: 1.0788815	total: 58.5ms	remaining: 1.89s
# 3:	learn: 1.0726016	total: 80ms	remaining: 1.92s
# 4:	learn: 1.0664174	total: 111ms	remaining: 2.11s
# 5:	learn: 1.0603854	total: 137ms	remaining: 2.14s
# 6:	learn: 1.0546345	total: 158ms	remaining: 2.1s
# 7:	learn: 1.0491352	total: 177ms	remaining: 2.04s
# 8:	learn: 1.0434342	total: 195ms	remaining: 1.97s
# 9:	learn: 1.0379896	total: 211ms	remaining: 1.9s
# 10:	learn: 1.0328149	total: 230ms	remaining: 1.86s
# 11:	learn: 1.0274773	total: 249ms	remaining: 1.83s
# 12:	learn: 1.0223561	total: 269ms	remaining: 1.8s
# 13:	learn: 1.0173688	total: 292ms	remaining: 1.79s
# 14:	learn: 1.0124022	total: 309ms	remaining: 1.75s
# 15:	learn: 1.0074958	total: 330ms	remaining: 1.73s
# 16:	learn: 1.0027164	total: 348ms	remaining: 1.7s
# 17:	learn: 0.9980890	total: 368ms	remaining: 1.68s
# 18:	learn: 0.9935275	total: 388ms	remaining: 1.66s
# 19:	learn: 0.9891527	total: 406ms	remaining: 1.62s
# 20:	learn: 0.9847914	total: 424ms	remaining: 1.59s
# 21:	learn: 0.9805106	total: 446ms	remaining: 1.58s
# 22:	learn: 0.9764144	total: 466ms	remaining: 1.56s
# 23:	learn: 0.9722834	total: 491ms	remaining: 1.55s
# 24:	learn: 0.9683357	total: 510ms	remaining: 1.53s
# 25:	learn: 0.9643355	total: 532ms	remaining: 1.51s
# 26:	learn: 0.9603815	total: 554ms	remaining: 1.5s
# 27:	learn: 0.9566701	total: 577ms	remaining: 1.48s
# 28:	learn: 0.9529126	total: 595ms	remaining: 1.46s
# 29:	learn: 0.9493688	total: 612ms	remaining: 1.43s
# 30:	learn: 0.9458356	total: 631ms	remaining: 1.4s
# 31:	learn: 0.9425553	total: 641ms	remaining: 1.36s
# 32:	learn: 0.9390635	total: 676ms	remaining: 1.37s
# 33:	learn: 0.9356121	total: 698ms	remaining: 1.35s
# 34:	learn: 0.9321932	total: 715ms	remaining: 1.33s
# 35:	learn: 0.9288569	total: 736ms	remaining: 1.31s
# 36:	learn: 0.9256402	total: 756ms	remaining: 1.29s
# 37:	learn: 0.9223847	total: 774ms	remaining: 1.26s
# 38:	learn: 0.9192312	total: 796ms	remaining: 1.24s
# 39:	learn: 0.9161033	total: 813ms	remaining: 1.22s
# 40:	learn: 0.9130509	total: 832ms	remaining: 1.2s
# 41:	learn: 0.9101402	total: 851ms	remaining: 1.17s
# 42:	learn: 0.9072950	total: 870ms	remaining: 1.15s
# 43:	learn: 0.9044254	total: 890ms	remaining: 1.13s
# 44:	learn: 0.9016266	total: 910ms	remaining: 1.11s
# 45:	learn: 0.8988832	total: 928ms	remaining: 1.09s
# 46:	learn: 0.8962352	total: 945ms	remaining: 1.07s
# 47:	learn: 0.8935220	total: 964ms	remaining: 1.04s
# 48:	learn: 0.8909247	total: 981ms	remaining: 1.02s
# 49:	learn: 0.8883789	total: 1s	remaining: 1s
# 50:	learn: 0.8857976	total: 1.02s	remaining: 979ms
# 51:	learn: 0.8833212	total: 1.03s	remaining: 956ms
# 52:	learn: 0.8808658	total: 1.05s	remaining: 935ms
# 53:	learn: 0.8784205	total: 1.07s	remaining: 914ms
# 54:	learn: 0.8761151	total: 1.09s	remaining: 894ms
# 55:	learn: 0.8739281	total: 1.1s	remaining: 868ms
# 56:	learn: 0.8715487	total: 1.13s	remaining: 849ms
# 57:	learn: 0.8694947	total: 1.14s	remaining: 828ms
# 58:	learn: 0.8673705	total: 1.16s	remaining: 808ms
# 59:	learn: 0.8652092	total: 1.18s	remaining: 788ms
# 60:	learn: 0.8630568	total: 1.2s	remaining: 767ms
# 61:	learn: 0.8608246	total: 1.22s	remaining: 748ms
# 62:	learn: 0.8588053	total: 1.24s	remaining: 727ms
# 63:	learn: 0.8566794	total: 1.25s	remaining: 706ms
# 64:	learn: 0.8546571	total: 1.27s	remaining: 686ms
# 65:	learn: 0.8527322	total: 1.3s	remaining: 670ms
# 66:	learn: 0.8507714	total: 1.32s	remaining: 650ms
# 67:	learn: 0.8487353	total: 1.34s	remaining: 631ms
# 68:	learn: 0.8467434	total: 1.36s	remaining: 611ms
# 69:	learn: 0.8449044	total: 1.38s	remaining: 591ms
# 70:	learn: 0.8431218	total: 1.4s	remaining: 571ms
# 71:	learn: 0.8412495	total: 1.41s	remaining: 550ms
# 72:	learn: 0.8393585	total: 1.44s	remaining: 531ms
# 73:	learn: 0.8375652	total: 1.46s	remaining: 511ms
# 74:	learn: 0.8357641	total: 1.47s	remaining: 492ms
# 75:	learn: 0.8340474	total: 1.5s	remaining: 473ms
# 76:	learn: 0.8323758	total: 1.51s	remaining: 453ms
# 77:	learn: 0.8307172	total: 1.53s	remaining: 433ms
# 78:	learn: 0.8289053	total: 1.56s	remaining: 414ms
# 79:	learn: 0.8273478	total: 1.57s	remaining: 394ms
# 80:	learn: 0.8258924	total: 1.59s	remaining: 372ms
# 81:	learn: 0.8243355	total: 1.6s	remaining: 352ms
# 82:	learn: 0.8227933	total: 1.62s	remaining: 332ms
# 83:	learn: 0.8212205	total: 1.64s	remaining: 313ms
# 84:	learn: 0.8196580	total: 1.66s	remaining: 293ms
# 85:	learn: 0.8181534	total: 1.68s	remaining: 273ms
# 86:	learn: 0.8168025	total: 1.7s	remaining: 253ms
# 87:	learn: 0.8154152	total: 1.71s	remaining: 234ms
# 88:	learn: 0.8140993	total: 1.74s	remaining: 215ms
# 89:	learn: 0.8128364	total: 1.76s	remaining: 195ms
# 90:	learn: 0.8114718	total: 1.78s	remaining: 176ms
# 91:	learn: 0.8101335	total: 1.8s	remaining: 156ms
# 92:	learn: 0.8087756	total: 1.82s	remaining: 137ms
# 93:	learn: 0.8075343	total: 1.83s	remaining: 117ms
# 94:	learn: 0.8063064	total: 1.86s	remaining: 97.7ms
# 95:	learn: 0.8049332	total: 1.88s	remaining: 78.1ms
# 96:	learn: 0.8035814	total: 1.9s	remaining: 58.7ms
# 97:	learn: 0.8023389	total: 1.92s	remaining: 39.1ms
# 98:	learn: 0.8010505	total: 1.93s	remaining: 19.5ms
# 99:	learn: 0.7997395	total: 1.96s	remaining: 0us
# 0:	learn: 1.0918134	total: 19ms	remaining: 1.88s
# 1:	learn: 1.0854019	total: 37.4ms	remaining: 1.83s
# 2:	learn: 1.0790885	total: 44.2ms	remaining: 1.43s
# 3:	learn: 1.0728066	total: 62.1ms	remaining: 1.49s
# 4:	learn: 1.0665953	total: 82.8ms	remaining: 1.57s
# 5:	learn: 1.0605650	total: 101ms	remaining: 1.59s
# 6:	learn: 1.0546198	total: 121ms	remaining: 1.61s
# 7:	learn: 1.0489638	total: 133ms	remaining: 1.53s
# 8:	learn: 1.0435923	total: 153ms	remaining: 1.55s
# 9:	learn: 1.0380871	total: 175ms	remaining: 1.58s
# 10:	learn: 1.0326069	total: 192ms	remaining: 1.55s
# 11:	learn: 1.0272467	total: 211ms	remaining: 1.54s
# 12:	learn: 1.0220993	total: 228ms	remaining: 1.53s
# 13:	learn: 1.0169079	total: 248ms	remaining: 1.52s
# 14:	learn: 1.0119084	total: 269ms	remaining: 1.52s
# 15:	learn: 1.0070279	total: 298ms	remaining: 1.56s
# 16:	learn: 1.0022206	total: 319ms	remaining: 1.56s
# 17:	learn: 0.9974233	total: 340ms	remaining: 1.55s
# 18:	learn: 0.9928548	total: 358ms	remaining: 1.52s
# 19:	learn: 0.9884555	total: 377ms	remaining: 1.51s
# 20:	learn: 0.9840863	total: 401ms	remaining: 1.51s
# 21:	learn: 0.9797465	total: 419ms	remaining: 1.48s
# 22:	learn: 0.9756520	total: 441ms	remaining: 1.48s
# 23:	learn: 0.9715674	total: 460ms	remaining: 1.46s
# 24:	learn: 0.9674664	total: 482ms	remaining: 1.45s
# 25:	learn: 0.9635853	total: 501ms	remaining: 1.43s
# 26:	learn: 0.9597898	total: 521ms	remaining: 1.41s
# 27:	learn: 0.9558623	total: 538ms	remaining: 1.38s
# 28:	learn: 0.9521543	total: 559ms	remaining: 1.37s
# 29:	learn: 0.9484238	total: 578ms	remaining: 1.35s
# 30:	learn: 0.9448780	total: 600ms	remaining: 1.33s
# 31:	learn: 0.9413786	total: 609ms	remaining: 1.29s
# 32:	learn: 0.9380568	total: 626ms	remaining: 1.27s
# 33:	learn: 0.9345924	total: 649ms	remaining: 1.26s
# 34:	learn: 0.9311881	total: 669ms	remaining: 1.24s
# 35:	learn: 0.9279848	total: 691ms	remaining: 1.23s
# 36:	learn: 0.9248940	total: 714ms	remaining: 1.22s
# 37:	learn: 0.9217143	total: 734ms	remaining: 1.2s
# 38:	learn: 0.9185492	total: 752ms	remaining: 1.18s
# 39:	learn: 0.9153998	total: 775ms	remaining: 1.16s
# 40:	learn: 0.9123571	total: 793ms	remaining: 1.14s
# 41:	learn: 0.9093424	total: 816ms	remaining: 1.13s
# 42:	learn: 0.9064486	total: 834ms	remaining: 1.1s
# 43:	learn: 0.9037577	total: 853ms	remaining: 1.09s
# 44:	learn: 0.9008736	total: 871ms	remaining: 1.06s
# 45:	learn: 0.8981469	total: 893ms	remaining: 1.05s
# 46:	learn: 0.8955774	total: 904ms	remaining: 1.02s
# 47:	learn: 0.8928524	total: 922ms	remaining: 999ms
# 48:	learn: 0.8901471	total: 940ms	remaining: 979ms
# 49:	learn: 0.8875138	total: 958ms	remaining: 958ms
# 50:	learn: 0.8849647	total: 977ms	remaining: 938ms
# 51:	learn: 0.8823925	total: 995ms	remaining: 919ms
# 52:	learn: 0.8797507	total: 1.01s	remaining: 899ms
# 53:	learn: 0.8772626	total: 1.03s	remaining: 880ms
# 54:	learn: 0.8748037	total: 1.05s	remaining: 861ms
# 55:	learn: 0.8724868	total: 1.07s	remaining: 844ms
# 56:	learn: 0.8702347	total: 1.09s	remaining: 826ms
# 57:	learn: 0.8679817	total: 1.12s	remaining: 809ms
# 58:	learn: 0.8658838	total: 1.14s	remaining: 792ms
# 59:	learn: 0.8636742	total: 1.16s	remaining: 772ms
# 60:	learn: 0.8615569	total: 1.17s	remaining: 746ms
# 61:	learn: 0.8592994	total: 1.19s	remaining: 728ms
# 62:	learn: 0.8571266	total: 1.21s	remaining: 709ms
# 63:	learn: 0.8553842	total: 1.21s	remaining: 681ms
# 64:	learn: 0.8532922	total: 1.23s	remaining: 663ms
# 65:	learn: 0.8512736	total: 1.25s	remaining: 645ms
# 66:	learn: 0.8492226	total: 1.27s	remaining: 626ms
# 67:	learn: 0.8474582	total: 1.29s	remaining: 608ms
# 68:	learn: 0.8455536	total: 1.31s	remaining: 590ms
# 69:	learn: 0.8436087	total: 1.33s	remaining: 571ms
# 70:	learn: 0.8417005	total: 1.35s	remaining: 553ms
# 71:	learn: 0.8398346	total: 1.37s	remaining: 534ms
# 72:	learn: 0.8380722	total: 1.39s	remaining: 515ms
# 73:	learn: 0.8362641	total: 1.41s	remaining: 496ms
# 74:	learn: 0.8343951	total: 1.43s	remaining: 477ms
# 75:	learn: 0.8327620	total: 1.45s	remaining: 458ms
# 76:	learn: 0.8310691	total: 1.48s	remaining: 441ms
# 77:	learn: 0.8293309	total: 1.5s	remaining: 423ms
# 78:	learn: 0.8276748	total: 1.52s	remaining: 406ms
# 79:	learn: 0.8259186	total: 1.54s	remaining: 386ms
# 80:	learn: 0.8242426	total: 1.56s	remaining: 367ms
# 81:	learn: 0.8226547	total: 1.58s	remaining: 348ms
# 82:	learn: 0.8211402	total: 1.6s	remaining: 329ms
# 83:	learn: 0.8197102	total: 1.62s	remaining: 309ms
# 84:	learn: 0.8181586	total: 1.64s	remaining: 290ms
# 85:	learn: 0.8164830	total: 1.66s	remaining: 271ms
# 86:	learn: 0.8149408	total: 1.69s	remaining: 252ms
# 87:	learn: 0.8134101	total: 1.71s	remaining: 233ms
# 88:	learn: 0.8120608	total: 1.73s	remaining: 213ms
# 89:	learn: 0.8106364	total: 1.75s	remaining: 194ms
# 90:	learn: 0.8091897	total: 1.76s	remaining: 174ms
# 91:	learn: 0.8077557	total: 1.78s	remaining: 155ms
# 92:	learn: 0.8063418	total: 1.8s	remaining: 136ms
# 93:	learn: 0.8050422	total: 1.82s	remaining: 116ms
# 94:	learn: 0.8038045	total: 1.84s	remaining: 96.9ms
# 95:	learn: 0.8025432	total: 1.86s	remaining: 77.5ms
# 96:	learn: 0.8012263	total: 1.88s	remaining: 58.1ms
# 97:	learn: 0.7999144	total: 1.9s	remaining: 38.8ms
# 98:	learn: 0.7987540	total: 1.92s	remaining: 19.4ms
# 99:	learn: 0.7974850	total: 1.94s	remaining: 0us
# 0:	learn: 1.0918639	total: 26.2ms	remaining: 2.6s
# 1:	learn: 1.0854983	total: 46.7ms	remaining: 2.29s
# 2:	learn: 1.0790361	total: 67.4ms	remaining: 2.18s
# 3:	learn: 1.0729703	total: 85.4ms	remaining: 2.05s
# 4:	learn: 1.0667507	total: 105ms	remaining: 2s
# 5:	learn: 1.0605748	total: 125ms	remaining: 1.97s
# 6:	learn: 1.0546728	total: 149ms	remaining: 1.97s
# 7:	learn: 1.0490091	total: 168ms	remaining: 1.93s
# 8:	learn: 1.0432746	total: 189ms	remaining: 1.91s
# 9:	learn: 1.0376922	total: 206ms	remaining: 1.85s
# 10:	learn: 1.0326126	total: 227ms	remaining: 1.84s
# 11:	learn: 1.0272351	total: 247ms	remaining: 1.81s
# 12:	learn: 1.0220663	total: 265ms	remaining: 1.77s
# 13:	learn: 1.0170275	total: 286ms	remaining: 1.76s
# 14:	learn: 1.0121082	total: 307ms	remaining: 1.74s
# 15:	learn: 1.0073412	total: 327ms	remaining: 1.72s
# 16:	learn: 1.0025465	total: 350ms	remaining: 1.71s
# 17:	learn: 0.9978881	total: 373ms	remaining: 1.7s
# 18:	learn: 0.9933180	total: 392ms	remaining: 1.67s
# 19:	learn: 0.9888451	total: 410ms	remaining: 1.64s
# 20:	learn: 0.9844032	total: 433ms	remaining: 1.63s
# 21:	learn: 0.9800663	total: 450ms	remaining: 1.59s
# 22:	learn: 0.9759431	total: 470ms	remaining: 1.57s
# 23:	learn: 0.9717952	total: 488ms	remaining: 1.54s
# 24:	learn: 0.9677920	total: 510ms	remaining: 1.53s
# 25:	learn: 0.9637238	total: 531ms	remaining: 1.51s
# 26:	learn: 0.9601346	total: 540ms	remaining: 1.46s
# 27:	learn: 0.9563390	total: 561ms	remaining: 1.44s
# 28:	learn: 0.9526345	total: 586ms	remaining: 1.43s
# 29:	learn: 0.9490403	total: 604ms	remaining: 1.41s
# 30:	learn: 0.9453010	total: 621ms	remaining: 1.38s
# 31:	learn: 0.9418761	total: 647ms	remaining: 1.38s
# 32:	learn: 0.9382743	total: 666ms	remaining: 1.35s
# 33:	learn: 0.9348635	total: 684ms	remaining: 1.33s
# 34:	learn: 0.9314806	total: 707ms	remaining: 1.31s
# 35:	learn: 0.9282609	total: 725ms	remaining: 1.29s
# 36:	learn: 0.9251486	total: 746ms	remaining: 1.27s
# 37:	learn: 0.9220626	total: 767ms	remaining: 1.25s
# 38:	learn: 0.9188461	total: 786ms	remaining: 1.23s
# 39:	learn: 0.9156896	total: 806ms	remaining: 1.21s
# 40:	learn: 0.9125929	total: 823ms	remaining: 1.18s
# 41:	learn: 0.9095272	total: 841ms	remaining: 1.16s
# 42:	learn: 0.9066316	total: 864ms	remaining: 1.14s
# 43:	learn: 0.9038406	total: 882ms	remaining: 1.12s
# 44:	learn: 0.9010274	total: 906ms	remaining: 1.11s
# 45:	learn: 0.8984092	total: 916ms	remaining: 1.07s
# 46:	learn: 0.8956001	total: 934ms	remaining: 1.05s
# 47:	learn: 0.8930200	total: 954ms	remaining: 1.03s
# 48:	learn: 0.8904020	total: 975ms	remaining: 1.01s
# 49:	learn: 0.8878598	total: 997ms	remaining: 997ms
# 50:	learn: 0.8852262	total: 1.02s	remaining: 978ms
# 51:	learn: 0.8827635	total: 1.04s	remaining: 957ms
# 52:	learn: 0.8802630	total: 1.05s	remaining: 936ms
# 53:	learn: 0.8777885	total: 1.07s	remaining: 916ms
# 54:	learn: 0.8754528	total: 1.09s	remaining: 896ms
# 55:	learn: 0.8730681	total: 1.12s	remaining: 877ms
# 56:	learn: 0.8707702	total: 1.14s	remaining: 858ms
# 57:	learn: 0.8686018	total: 1.16s	remaining: 837ms
# 58:	learn: 0.8663593	total: 1.18s	remaining: 822ms
# 59:	learn: 0.8641816	total: 1.21s	remaining: 806ms
# 60:	learn: 0.8619813	total: 1.23s	remaining: 786ms
# 61:	learn: 0.8598827	total: 1.25s	remaining: 765ms
# 62:	learn: 0.8577920	total: 1.27s	remaining: 745ms
# 63:	learn: 0.8557087	total: 1.29s	remaining: 726ms
# 64:	learn: 0.8536153	total: 1.31s	remaining: 705ms
# 65:	learn: 0.8516073	total: 1.33s	remaining: 685ms
# 66:	learn: 0.8497227	total: 1.35s	remaining: 665ms
# 67:	learn: 0.8477930	total: 1.37s	remaining: 645ms
# 68:	learn: 0.8458686	total: 1.39s	remaining: 625ms
# 69:	learn: 0.8439150	total: 1.41s	remaining: 604ms
# 70:	learn: 0.8420852	total: 1.43s	remaining: 584ms
# 71:	learn: 0.8403528	total: 1.44s	remaining: 559ms
# 72:	learn: 0.8386022	total: 1.46s	remaining: 539ms
# 73:	learn: 0.8367720	total: 1.47s	remaining: 518ms
# 74:	learn: 0.8350997	total: 1.5s	remaining: 499ms
# 75:	learn: 0.8335469	total: 1.52s	remaining: 479ms
# 76:	learn: 0.8319679	total: 1.53s	remaining: 459ms
# 77:	learn: 0.8302413	total: 1.55s	remaining: 438ms
# 78:	learn: 0.8285547	total: 1.57s	remaining: 418ms
# 79:	learn: 0.8268545	total: 1.59s	remaining: 399ms
# 80:	learn: 0.8252996	total: 1.62s	remaining: 379ms
# 81:	learn: 0.8236310	total: 1.64s	remaining: 359ms
# 82:	learn: 0.8221170	total: 1.65s	remaining: 339ms
# 83:	learn: 0.8206752	total: 1.67s	remaining: 318ms
# 84:	learn: 0.8191870	total: 1.69s	remaining: 299ms
# 85:	learn: 0.8179103	total: 1.71s	remaining: 279ms
# 86:	learn: 0.8166443	total: 1.73s	remaining: 259ms
# 87:	learn: 0.8151391	total: 1.75s	remaining: 239ms
# 88:	learn: 0.8136953	total: 1.77s	remaining: 219ms
# 89:	learn: 0.8123166	total: 1.79s	remaining: 199ms
# 90:	learn: 0.8110606	total: 1.81s	remaining: 179ms
# 91:	learn: 0.8096167	total: 1.83s	remaining: 159ms
# 92:	learn: 0.8082184	total: 1.84s	remaining: 139ms
# 93:	learn: 0.8067668	total: 1.86s	remaining: 119ms
# 94:	learn: 0.8054925	total: 1.88s	remaining: 99.1ms
# 95:	learn: 0.8043202	total: 1.9s	remaining: 79.3ms
# 96:	learn: 0.8031009	total: 1.92s	remaining: 59.5ms
# 97:	learn: 0.8017383	total: 1.94s	remaining: 39.6ms
# 98:	learn: 0.8004792	total: 1.96s	remaining: 19.8ms
# 99:	learn: 0.7992997	total: 1.98s	remaining: 0us
# 0:	learn: 1.0345953	total: 18.2ms	remaining: 1.8s
# 1:	learn: 0.9862666	total: 35.5ms	remaining: 1.74s
# 2:	learn: 0.9476468	total: 42.3ms	remaining: 1.37s
# 3:	learn: 0.9146017	total: 62.6ms	remaining: 1.5s
# 4:	learn: 0.8865399	total: 84.7ms	remaining: 1.61s
# 5:	learn: 0.8631028	total: 105ms	remaining: 1.64s
# 6:	learn: 0.8435995	total: 122ms	remaining: 1.62s
# 7:	learn: 0.8266555	total: 143ms	remaining: 1.64s
# 8:	learn: 0.8119665	total: 161ms	remaining: 1.63s
# 9:	learn: 0.8021024	total: 168ms	remaining: 1.51s
# 10:	learn: 0.7925233	total: 187ms	remaining: 1.51s
# 11:	learn: 0.7828608	total: 207ms	remaining: 1.52s
# 12:	learn: 0.7750730	total: 226ms	remaining: 1.51s
# 13:	learn: 0.7673527	total: 243ms	remaining: 1.5s
# 14:	learn: 0.7606941	total: 264ms	remaining: 1.5s
# 15:	learn: 0.7548053	total: 282ms	remaining: 1.48s
# 16:	learn: 0.7503348	total: 307ms	remaining: 1.5s
# 17:	learn: 0.7454467	total: 329ms	remaining: 1.5s
# 18:	learn: 0.7416807	total: 353ms	remaining: 1.5s
# 19:	learn: 0.7373427	total: 371ms	remaining: 1.49s
# 20:	learn: 0.7324270	total: 391ms	remaining: 1.47s
# 21:	learn: 0.7293329	total: 409ms	remaining: 1.45s
# 22:	learn: 0.7252369	total: 430ms	remaining: 1.44s
# 23:	learn: 0.7220084	total: 448ms	remaining: 1.42s
# 24:	learn: 0.7194158	total: 470ms	remaining: 1.41s
# 25:	learn: 0.7161565	total: 488ms	remaining: 1.39s
# 26:	learn: 0.7125794	total: 507ms	remaining: 1.37s
# 27:	learn: 0.7099969	total: 526ms	remaining: 1.35s
# 28:	learn: 0.7073779	total: 543ms	remaining: 1.33s
# 29:	learn: 0.7053206	total: 563ms	remaining: 1.31s
# 30:	learn: 0.7036307	total: 583ms	remaining: 1.3s
# 31:	learn: 0.7010406	total: 600ms	remaining: 1.27s
# 32:	learn: 0.6996330	total: 619ms	remaining: 1.26s
# 33:	learn: 0.6979362	total: 641ms	remaining: 1.24s
# 34:	learn: 0.6963356	total: 661ms	remaining: 1.23s
# 35:	learn: 0.6953393	total: 680ms	remaining: 1.21s
# 36:	learn: 0.6943713	total: 697ms	remaining: 1.19s
# 37:	learn: 0.6926184	total: 717ms	remaining: 1.17s
# 38:	learn: 0.6908059	total: 735ms	remaining: 1.15s
# 39:	learn: 0.6893224	total: 753ms	remaining: 1.13s
# 40:	learn: 0.6881885	total: 773ms	remaining: 1.11s
# 41:	learn: 0.6873279	total: 791ms	remaining: 1.09s
# 42:	learn: 0.6862254	total: 807ms	remaining: 1.07s
# 43:	learn: 0.6855329	total: 825ms	remaining: 1.05s
# 44:	learn: 0.6837985	total: 843ms	remaining: 1.03s
# 45:	learn: 0.6823219	total: 865ms	remaining: 1.01s
# 46:	learn: 0.6812009	total: 886ms	remaining: 999ms
# 47:	learn: 0.6799826	total: 905ms	remaining: 980ms
# 48:	learn: 0.6789269	total: 925ms	remaining: 963ms
# 49:	learn: 0.6777742	total: 944ms	remaining: 944ms
# 50:	learn: 0.6767740	total: 963ms	remaining: 926ms
# 51:	learn: 0.6756179	total: 986ms	remaining: 910ms
# 52:	learn: 0.6742438	total: 1s	remaining: 890ms
# 53:	learn: 0.6727227	total: 1.02s	remaining: 870ms
# 54:	learn: 0.6714991	total: 1.04s	remaining: 851ms
# 55:	learn: 0.6714173	total: 1.05s	remaining: 823ms
# 56:	learn: 0.6703737	total: 1.06s	remaining: 804ms
# 57:	learn: 0.6699030	total: 1.08s	remaining: 786ms
# 58:	learn: 0.6697119	total: 1.09s	remaining: 760ms
# 59:	learn: 0.6693378	total: 1.11s	remaining: 741ms
# 60:	learn: 0.6681533	total: 1.13s	remaining: 723ms
# 61:	learn: 0.6669613	total: 1.15s	remaining: 704ms
# 62:	learn: 0.6660682	total: 1.17s	remaining: 685ms
# 63:	learn: 0.6654608	total: 1.19s	remaining: 667ms
# 64:	learn: 0.6643654	total: 1.21s	remaining: 650ms
# 65:	learn: 0.6639337	total: 1.22s	remaining: 631ms
# 66:	learn: 0.6630566	total: 1.24s	remaining: 612ms
# 67:	learn: 0.6622627	total: 1.26s	remaining: 594ms
# 68:	learn: 0.6617813	total: 1.29s	remaining: 579ms
# 69:	learn: 0.6605163	total: 1.31s	remaining: 560ms
# 70:	learn: 0.6599840	total: 1.32s	remaining: 541ms
# 71:	learn: 0.6596744	total: 1.34s	remaining: 523ms
# 72:	learn: 0.6590180	total: 1.36s	remaining: 504ms
# 73:	learn: 0.6580987	total: 1.38s	remaining: 486ms
# 74:	learn: 0.6571548	total: 1.41s	remaining: 470ms
# 75:	learn: 0.6561327	total: 1.43s	remaining: 451ms
# 76:	learn: 0.6555699	total: 1.45s	remaining: 433ms
# 77:	learn: 0.6551710	total: 1.47s	remaining: 416ms
# 78:	learn: 0.6526282	total: 1.5s	remaining: 398ms
# 79:	learn: 0.6518053	total: 1.52s	remaining: 380ms
# 80:	learn: 0.6514631	total: 1.54s	remaining: 362ms
# 81:	learn: 0.6504606	total: 1.57s	remaining: 344ms
# 82:	learn: 0.6499219	total: 1.59s	remaining: 326ms
# 83:	learn: 0.6495619	total: 1.61s	remaining: 307ms
# 84:	learn: 0.6495179	total: 1.61s	remaining: 285ms
# 85:	learn: 0.6484314	total: 1.63s	remaining: 266ms
# 86:	learn: 0.6471749	total: 1.65s	remaining: 247ms
# 87:	learn: 0.6469175	total: 1.67s	remaining: 228ms
# 88:	learn: 0.6462411	total: 1.69s	remaining: 209ms
# 89:	learn: 0.6458169	total: 1.72s	remaining: 191ms
# 90:	learn: 0.6453034	total: 1.73s	remaining: 171ms
# 91:	learn: 0.6441705	total: 1.75s	remaining: 152ms
# 92:	learn: 0.6434215	total: 1.77s	remaining: 133ms
# 93:	learn: 0.6428810	total: 1.79s	remaining: 114ms
# 94:	learn: 0.6419684	total: 1.81s	remaining: 95.1ms
# 95:	learn: 0.6409023	total: 1.82s	remaining: 76.1ms
# 96:	learn: 0.6395994	total: 1.84s	remaining: 57ms
# 97:	learn: 0.6386595	total: 1.86s	remaining: 38ms
# 98:	learn: 0.6383231	total: 1.88s	remaining: 19ms
# 99:	learn: 0.6368251	total: 1.9s	remaining: 0us
# 0:	learn: 1.0335420	total: 19.6ms	remaining: 1.94s
# 1:	learn: 0.9843550	total: 40.7ms	remaining: 2s
# 2:	learn: 0.9433860	total: 59.3ms	remaining: 1.92s
# 3:	learn: 0.9107791	total: 78.6ms	remaining: 1.89s
# 4:	learn: 0.8826411	total: 100ms	remaining: 1.91s
# 5:	learn: 0.8584919	total: 123ms	remaining: 1.92s
# 6:	learn: 0.8394753	total: 144ms	remaining: 1.91s
# 7:	learn: 0.8226535	total: 162ms	remaining: 1.86s
# 8:	learn: 0.8068166	total: 186ms	remaining: 1.88s
# 9:	learn: 0.7949468	total: 206ms	remaining: 1.85s
# 10:	learn: 0.7844145	total: 227ms	remaining: 1.83s
# 11:	learn: 0.7749748	total: 247ms	remaining: 1.81s
# 12:	learn: 0.7665660	total: 268ms	remaining: 1.79s
# 13:	learn: 0.7583734	total: 286ms	remaining: 1.75s
# 14:	learn: 0.7513611	total: 305ms	remaining: 1.73s
# 15:	learn: 0.7456321	total: 327ms	remaining: 1.71s
# 16:	learn: 0.7388584	total: 347ms	remaining: 1.69s
# 17:	learn: 0.7332507	total: 365ms	remaining: 1.66s
# 18:	learn: 0.7294649	total: 383ms	remaining: 1.63s
# 19:	learn: 0.7260956	total: 404ms	remaining: 1.61s
# 20:	learn: 0.7225688	total: 421ms	remaining: 1.58s
# 21:	learn: 0.7181774	total: 442ms	remaining: 1.57s
# 22:	learn: 0.7149759	total: 463ms	remaining: 1.55s
# 23:	learn: 0.7117180	total: 481ms	remaining: 1.52s
# 24:	learn: 0.7088935	total: 502ms	remaining: 1.5s
# 25:	learn: 0.7053557	total: 521ms	remaining: 1.48s
# 26:	learn: 0.7028369	total: 542ms	remaining: 1.46s
# 27:	learn: 0.7011397	total: 563ms	remaining: 1.45s
# 28:	learn: 0.6986913	total: 581ms	remaining: 1.42s
# 29:	learn: 0.6968601	total: 601ms	remaining: 1.4s
# 30:	learn: 0.6949885	total: 624ms	remaining: 1.39s
# 31:	learn: 0.6936838	total: 645ms	remaining: 1.37s
# 32:	learn: 0.6916755	total: 665ms	remaining: 1.35s
# 33:	learn: 0.6899915	total: 684ms	remaining: 1.33s
# 34:	learn: 0.6882696	total: 707ms	remaining: 1.31s
# 35:	learn: 0.6859594	total: 727ms	remaining: 1.29s
# 36:	learn: 0.6842884	total: 748ms	remaining: 1.27s
# 37:	learn: 0.6834501	total: 767ms	remaining: 1.25s
# 38:	learn: 0.6814608	total: 785ms	remaining: 1.23s
# 39:	learn: 0.6797983	total: 802ms	remaining: 1.2s
# 40:	learn: 0.6787903	total: 822ms	remaining: 1.18s
# 41:	learn: 0.6776613	total: 841ms	remaining: 1.16s
# 42:	learn: 0.6766474	total: 865ms	remaining: 1.15s
# 43:	learn: 0.6757741	total: 885ms	remaining: 1.13s
# 44:	learn: 0.6746822	total: 904ms	remaining: 1.1s
# 45:	learn: 0.6737232	total: 925ms	remaining: 1.09s
# 46:	learn: 0.6734759	total: 931ms	remaining: 1.05s
# 47:	learn: 0.6728966	total: 952ms	remaining: 1.03s
# 48:	learn: 0.6714868	total: 971ms	remaining: 1.01s
# 49:	learn: 0.6703302	total: 990ms	remaining: 990ms
# 50:	learn: 0.6693626	total: 1.01s	remaining: 970ms
# 51:	learn: 0.6685498	total: 1.03s	remaining: 948ms
# 52:	learn: 0.6676961	total: 1.05s	remaining: 930ms
# 53:	learn: 0.6661944	total: 1.07s	remaining: 915ms
# 54:	learn: 0.6640027	total: 1.1s	remaining: 899ms
# 55:	learn: 0.6634113	total: 1.12s	remaining: 880ms
# 56:	learn: 0.6624170	total: 1.14s	remaining: 860ms
# 57:	learn: 0.6618537	total: 1.16s	remaining: 841ms
# 58:	learn: 0.6610732	total: 1.18s	remaining: 822ms
# 59:	learn: 0.6591626	total: 1.2s	remaining: 802ms
# 60:	learn: 0.6585453	total: 1.22s	remaining: 780ms
# 61:	learn: 0.6575620	total: 1.24s	remaining: 760ms
# 62:	learn: 0.6565698	total: 1.26s	remaining: 741ms
# 63:	learn: 0.6559132	total: 1.28s	remaining: 721ms
# 64:	learn: 0.6546859	total: 1.3s	remaining: 700ms
# 65:	learn: 0.6537178	total: 1.32s	remaining: 681ms
# 66:	learn: 0.6532407	total: 1.34s	remaining: 660ms
# 67:	learn: 0.6526488	total: 1.36s	remaining: 640ms
# 68:	learn: 0.6511266	total: 1.38s	remaining: 620ms
# 69:	learn: 0.6500924	total: 1.4s	remaining: 600ms
# 70:	learn: 0.6477602	total: 1.42s	remaining: 580ms
# 71:	learn: 0.6473689	total: 1.44s	remaining: 559ms
# 72:	learn: 0.6466942	total: 1.46s	remaining: 539ms
# 73:	learn: 0.6456288	total: 1.48s	remaining: 521ms
# 74:	learn: 0.6448040	total: 1.5s	remaining: 501ms
# 75:	learn: 0.6436479	total: 1.52s	remaining: 480ms
# 76:	learn: 0.6424187	total: 1.55s	remaining: 462ms
# 77:	learn: 0.6422370	total: 1.55s	remaining: 438ms
# 78:	learn: 0.6420469	total: 1.57s	remaining: 418ms
# 79:	learn: 0.6413486	total: 1.59s	remaining: 397ms
# 80:	learn: 0.6406204	total: 1.61s	remaining: 378ms
# 81:	learn: 0.6396773	total: 1.63s	remaining: 358ms
# 82:	learn: 0.6383019	total: 1.65s	remaining: 338ms
# 83:	learn: 0.6376364	total: 1.67s	remaining: 317ms
# 84:	learn: 0.6368965	total: 1.68s	remaining: 297ms
# 85:	learn: 0.6363370	total: 1.7s	remaining: 277ms
# 86:	learn: 0.6361772	total: 1.72s	remaining: 257ms
# 87:	learn: 0.6358006	total: 1.74s	remaining: 237ms
# 88:	learn: 0.6345345	total: 1.76s	remaining: 217ms
# 89:	learn: 0.6334125	total: 1.78s	remaining: 197ms
# 90:	learn: 0.6330164	total: 1.79s	remaining: 178ms
# 91:	learn: 0.6325998	total: 1.81s	remaining: 158ms
# 92:	learn: 0.6320891	total: 1.83s	remaining: 138ms
# 93:	learn: 0.6315619	total: 1.85s	remaining: 118ms
# 94:	learn: 0.6311238	total: 1.86s	remaining: 98.1ms
# 95:	learn: 0.6301112	total: 1.88s	remaining: 78.5ms
# 96:	learn: 0.6290406	total: 1.9s	remaining: 58.9ms
# 97:	learn: 0.6284200	total: 1.92s	remaining: 39.3ms
# 98:	learn: 0.6272137	total: 1.95s	remaining: 19.7ms
# 99:	learn: 0.6264449	total: 1.97s	remaining: 0us
# 0:	learn: 1.0338321	total: 17.9ms	remaining: 1.77s
# 1:	learn: 0.9841292	total: 34.8ms	remaining: 1.71s
# 2:	learn: 0.9433024	total: 52.1ms	remaining: 1.68s
# 3:	learn: 0.9110391	total: 70.1ms	remaining: 1.68s
# 4:	learn: 0.8834923	total: 91.9ms	remaining: 1.75s
# 5:	learn: 0.8593768	total: 116ms	remaining: 1.82s
# 6:	learn: 0.8389630	total: 149ms	remaining: 1.98s
# 7:	learn: 0.8224855	total: 173ms	remaining: 1.99s
# 8:	learn: 0.8071028	total: 193ms	remaining: 1.95s
# 9:	learn: 0.7962052	total: 211ms	remaining: 1.9s
# 10:	learn: 0.7859323	total: 232ms	remaining: 1.88s
# 11:	learn: 0.7766925	total: 251ms	remaining: 1.84s
# 12:	learn: 0.7680618	total: 271ms	remaining: 1.82s
# 13:	learn: 0.7607630	total: 293ms	remaining: 1.8s
# 14:	learn: 0.7535818	total: 313ms	remaining: 1.77s
# 15:	learn: 0.7472779	total: 333ms	remaining: 1.75s
# 16:	learn: 0.7417879	total: 354ms	remaining: 1.73s
# 17:	learn: 0.7369447	total: 376ms	remaining: 1.71s
# 18:	learn: 0.7334164	total: 397ms	remaining: 1.69s
# 19:	learn: 0.7290459	total: 416ms	remaining: 1.66s
# 20:	learn: 0.7262261	total: 435ms	remaining: 1.64s
# 21:	learn: 0.7215571	total: 454ms	remaining: 1.61s
# 22:	learn: 0.7187849	total: 478ms	remaining: 1.6s
# 23:	learn: 0.7159387	total: 499ms	remaining: 1.58s
# 24:	learn: 0.7131085	total: 518ms	remaining: 1.55s
# 25:	learn: 0.7099913	total: 539ms	remaining: 1.53s
# 26:	learn: 0.7074856	total: 556ms	remaining: 1.5s
# 27:	learn: 0.7053914	total: 575ms	remaining: 1.48s
# 28:	learn: 0.7035545	total: 594ms	remaining: 1.45s
# 29:	learn: 0.7023560	total: 611ms	remaining: 1.43s
# 30:	learn: 0.7004685	total: 629ms	remaining: 1.4s
# 31:	learn: 0.6988663	total: 649ms	remaining: 1.38s
# 32:	learn: 0.6975768	total: 667ms	remaining: 1.35s
# 33:	learn: 0.6951510	total: 686ms	remaining: 1.33s
# 34:	learn: 0.6932858	total: 708ms	remaining: 1.31s
# 35:	learn: 0.6914427	total: 727ms	remaining: 1.29s
# 36:	learn: 0.6899931	total: 747ms	remaining: 1.27s
# 37:	learn: 0.6890411	total: 767ms	remaining: 1.25s
# 38:	learn: 0.6870081	total: 790ms	remaining: 1.23s
# 39:	learn: 0.6850119	total: 811ms	remaining: 1.22s
# 40:	learn: 0.6827081	total: 832ms	remaining: 1.2s
# 41:	learn: 0.6817857	total: 856ms	remaining: 1.18s
# 42:	learn: 0.6802961	total: 881ms	remaining: 1.17s
# 43:	learn: 0.6795686	total: 904ms	remaining: 1.15s
# 44:	learn: 0.6779695	total: 928ms	remaining: 1.13s
# 45:	learn: 0.6761482	total: 951ms	remaining: 1.12s
# 46:	learn: 0.6758339	total: 959ms	remaining: 1.08s
# 47:	learn: 0.6738311	total: 981ms	remaining: 1.06s
# 48:	learn: 0.6729021	total: 1s	remaining: 1.04s
# 49:	learn: 0.6722955	total: 1.02s	remaining: 1.02s
# 50:	learn: 0.6712824	total: 1.04s	remaining: 1s
# 51:	learn: 0.6702008	total: 1.07s	remaining: 987ms
# 52:	learn: 0.6694970	total: 1.09s	remaining: 967ms
# 53:	learn: 0.6684746	total: 1.11s	remaining: 947ms
# 54:	learn: 0.6680013	total: 1.13s	remaining: 927ms
# 55:	learn: 0.6669811	total: 1.15s	remaining: 907ms
# 56:	learn: 0.6660141	total: 1.18s	remaining: 888ms
# 57:	learn: 0.6653180	total: 1.2s	remaining: 869ms
# 58:	learn: 0.6644105	total: 1.22s	remaining: 848ms
# 59:	learn: 0.6637161	total: 1.24s	remaining: 827ms
# 60:	learn: 0.6619610	total: 1.26s	remaining: 807ms
# 61:	learn: 0.6611106	total: 1.29s	remaining: 788ms
# 62:	learn: 0.6600951	total: 1.31s	remaining: 769ms
# 63:	learn: 0.6590780	total: 1.33s	remaining: 749ms
# 64:	learn: 0.6577986	total: 1.35s	remaining: 728ms
# 65:	learn: 0.6571846	total: 1.37s	remaining: 707ms
# 66:	learn: 0.6568319	total: 1.39s	remaining: 686ms
# 67:	learn: 0.6562823	total: 1.41s	remaining: 666ms
# 68:	learn: 0.6536526	total: 1.44s	remaining: 645ms
# 69:	learn: 0.6527043	total: 1.46s	remaining: 626ms
# 70:	learn: 0.6506889	total: 1.48s	remaining: 606ms
# 71:	learn: 0.6493974	total: 1.5s	remaining: 585ms
# 72:	learn: 0.6481873	total: 1.53s	remaining: 566ms
# 73:	learn: 0.6476825	total: 1.55s	remaining: 546ms
# 74:	learn: 0.6461199	total: 1.57s	remaining: 525ms
# 75:	learn: 0.6453918	total: 1.59s	remaining: 504ms
# 76:	learn: 0.6444082	total: 1.62s	remaining: 483ms
# 77:	learn: 0.6440891	total: 1.64s	remaining: 462ms
# 78:	learn: 0.6437642	total: 1.66s	remaining: 441ms
# 79:	learn: 0.6433826	total: 1.68s	remaining: 420ms
# 80:	learn: 0.6430376	total: 1.71s	remaining: 400ms
# 81:	learn: 0.6426115	total: 1.73s	remaining: 379ms
# 82:	learn: 0.6420615	total: 1.75s	remaining: 358ms
# 83:	learn: 0.6414742	total: 1.77s	remaining: 337ms
# 84:	learn: 0.6410813	total: 1.79s	remaining: 316ms
# 85:	learn: 0.6405787	total: 1.81s	remaining: 295ms
# 86:	learn: 0.6394362	total: 1.84s	remaining: 275ms
# 87:	learn: 0.6386947	total: 1.86s	remaining: 254ms
# 88:	learn: 0.6380147	total: 1.88s	remaining: 233ms
# 89:	learn: 0.6371460	total: 1.91s	remaining: 212ms
# 90:	learn: 0.6366987	total: 1.93s	remaining: 191ms
# 91:	learn: 0.6358754	total: 1.95s	remaining: 170ms
# 92:	learn: 0.6350218	total: 1.97s	remaining: 149ms
# 93:	learn: 0.6342636	total: 2s	remaining: 127ms
# 94:	learn: 0.6334763	total: 2.02s	remaining: 106ms
# 95:	learn: 0.6318303	total: 2.04s	remaining: 85.1ms
# 96:	learn: 0.6310330	total: 2.07s	remaining: 63.9ms
# 97:	learn: 0.6303537	total: 2.09s	remaining: 42.6ms
# 98:	learn: 0.6290544	total: 2.11s	remaining: 21.3ms
# 99:	learn: 0.6282686	total: 2.13s	remaining: 0us
# 0:	learn: 1.0336287	total: 20.2ms	remaining: 2s
# 1:	learn: 0.9843241	total: 40.5ms	remaining: 1.98s
# 2:	learn: 0.9428506	total: 61ms	remaining: 1.97s
# 3:	learn: 0.9102380	total: 83.3ms	remaining: 2s
# 4:	learn: 0.8820542	total: 111ms	remaining: 2.11s
# 5:	learn: 0.8579416	total: 131ms	remaining: 2.05s
# 6:	learn: 0.8379828	total: 154ms	remaining: 2.05s
# 7:	learn: 0.8224644	total: 175ms	remaining: 2.01s
# 8:	learn: 0.8082212	total: 195ms	remaining: 1.97s
# 9:	learn: 0.7977912	total: 206ms	remaining: 1.85s
# 10:	learn: 0.7886722	total: 216ms	remaining: 1.75s
# 11:	learn: 0.7790459	total: 237ms	remaining: 1.74s
# 12:	learn: 0.7709570	total: 257ms	remaining: 1.72s
# 13:	learn: 0.7616739	total: 278ms	remaining: 1.71s
# 14:	learn: 0.7533676	total: 303ms	remaining: 1.72s
# 15:	learn: 0.7477015	total: 326ms	remaining: 1.71s
# 16:	learn: 0.7418664	total: 346ms	remaining: 1.69s
# 17:	learn: 0.7359254	total: 371ms	remaining: 1.69s
# 18:	learn: 0.7326966	total: 381ms	remaining: 1.62s
# 19:	learn: 0.7285723	total: 402ms	remaining: 1.61s
# 20:	learn: 0.7248945	total: 422ms	remaining: 1.59s
# 21:	learn: 0.7208697	total: 445ms	remaining: 1.58s
# 22:	learn: 0.7166900	total: 467ms	remaining: 1.56s
# 23:	learn: 0.7128898	total: 493ms	remaining: 1.56s
# 24:	learn: 0.7094811	total: 518ms	remaining: 1.55s
# 25:	learn: 0.7066637	total: 540ms	remaining: 1.54s
# 26:	learn: 0.7044164	total: 563ms	remaining: 1.52s
# 27:	learn: 0.7026032	total: 584ms	remaining: 1.5s
# 28:	learn: 0.7000856	total: 605ms	remaining: 1.48s
# 29:	learn: 0.6977368	total: 627ms	remaining: 1.46s
# 30:	learn: 0.6951019	total: 650ms	remaining: 1.45s
# 31:	learn: 0.6925132	total: 670ms	remaining: 1.42s
# 32:	learn: 0.6909028	total: 693ms	remaining: 1.41s
# 33:	learn: 0.6888089	total: 714ms	remaining: 1.39s
# 34:	learn: 0.6870811	total: 736ms	remaining: 1.37s
# 35:	learn: 0.6858848	total: 757ms	remaining: 1.34s
# 36:	learn: 0.6845090	total: 780ms	remaining: 1.33s
# 37:	learn: 0.6829999	total: 802ms	remaining: 1.31s
# 38:	learn: 0.6821906	total: 823ms	remaining: 1.29s
# 39:	learn: 0.6809165	total: 845ms	remaining: 1.27s
# 40:	learn: 0.6794636	total: 867ms	remaining: 1.25s
# 41:	learn: 0.6783078	total: 888ms	remaining: 1.23s
# 42:	learn: 0.6773741	total: 912ms	remaining: 1.21s
# 43:	learn: 0.6768209	total: 932ms	remaining: 1.19s
# 44:	learn: 0.6765256	total: 939ms	remaining: 1.15s
# 45:	learn: 0.6751342	total: 962ms	remaining: 1.13s
# 46:	learn: 0.6728028	total: 987ms	remaining: 1.11s
# 47:	learn: 0.6716771	total: 1.01s	remaining: 1.09s
# 48:	learn: 0.6709062	total: 1.03s	remaining: 1.07s
# 49:	learn: 0.6701175	total: 1.05s	remaining: 1.05s
# 50:	learn: 0.6692654	total: 1.07s	remaining: 1.03s
# 51:	learn: 0.6682804	total: 1.1s	remaining: 1.01s
# 52:	learn: 0.6658488	total: 1.12s	remaining: 993ms
# 53:	learn: 0.6651724	total: 1.14s	remaining: 975ms
# 54:	learn: 0.6647528	total: 1.17s	remaining: 956ms
# 55:	learn: 0.6637639	total: 1.19s	remaining: 935ms
# 56:	learn: 0.6626579	total: 1.21s	remaining: 914ms
# 57:	learn: 0.6621949	total: 1.22s	remaining: 884ms
# 58:	learn: 0.6616348	total: 1.24s	remaining: 863ms
# 59:	learn: 0.6612016	total: 1.26s	remaining: 843ms
# 60:	learn: 0.6602602	total: 1.29s	remaining: 825ms
# 61:	learn: 0.6598417	total: 1.31s	remaining: 806ms
# 62:	learn: 0.6582299	total: 1.34s	remaining: 789ms
# 63:	learn: 0.6573846	total: 1.37s	remaining: 771ms
# 64:	learn: 0.6566979	total: 1.4s	remaining: 753ms
# 65:	learn: 0.6563183	total: 1.43s	remaining: 734ms
# 66:	learn: 0.6553136	total: 1.45s	remaining: 715ms
# 67:	learn: 0.6549898	total: 1.47s	remaining: 690ms
# 68:	learn: 0.6541994	total: 1.5s	remaining: 675ms
# 69:	learn: 0.6538555	total: 1.53s	remaining: 656ms
# 70:	learn: 0.6528582	total: 1.56s	remaining: 636ms
# 71:	learn: 0.6522145	total: 1.58s	remaining: 617ms
# 72:	learn: 0.6516134	total: 1.61s	remaining: 596ms
# 73:	learn: 0.6511174	total: 1.64s	remaining: 576ms
# 74:	learn: 0.6500270	total: 1.67s	remaining: 556ms
# 75:	learn: 0.6496995	total: 1.69s	remaining: 534ms
# 76:	learn: 0.6490613	total: 1.71s	remaining: 512ms
# 77:	learn: 0.6485390	total: 1.74s	remaining: 489ms
# 78:	learn: 0.6477004	total: 1.76s	remaining: 467ms
# 79:	learn: 0.6471127	total: 1.78s	remaining: 444ms
# 80:	learn: 0.6467188	total: 1.8s	remaining: 422ms
# 81:	learn: 0.6459395	total: 1.82s	remaining: 400ms
# 82:	learn: 0.6447640	total: 1.84s	remaining: 378ms
# 83:	learn: 0.6440074	total: 1.87s	remaining: 356ms
# 84:	learn: 0.6437115	total: 1.89s	remaining: 333ms
# 85:	learn: 0.6428522	total: 1.91s	remaining: 311ms
# 86:	learn: 0.6420090	total: 1.93s	remaining: 289ms
# 87:	learn: 0.6415066	total: 1.96s	remaining: 267ms
# 88:	learn: 0.6407127	total: 1.98s	remaining: 244ms
# 89:	learn: 0.6398064	total: 2s	remaining: 222ms
# 90:	learn: 0.6394988	total: 2.02s	remaining: 200ms
# 91:	learn: 0.6390932	total: 2.04s	remaining: 177ms
# 92:	learn: 0.6378663	total: 2.06s	remaining: 155ms
# 93:	learn: 0.6356833	total: 2.09s	remaining: 133ms
# 94:	learn: 0.6349221	total: 2.11s	remaining: 111ms
# 95:	learn: 0.6335763	total: 2.13s	remaining: 88.6ms
# 96:	learn: 0.6323063	total: 2.15s	remaining: 66.5ms
# 97:	learn: 0.6311190	total: 2.17s	remaining: 44.4ms
# 98:	learn: 0.6303831	total: 2.2s	remaining: 22.2ms
# 99:	learn: 0.6298450	total: 2.23s	remaining: 0us
# 0:	learn: 1.0341298	total: 21.4ms	remaining: 2.12s
# 1:	learn: 0.9853476	total: 45.8ms	remaining: 2.25s
# 2:	learn: 0.9444407	total: 67.2ms	remaining: 2.17s
# 3:	learn: 0.9121176	total: 90.4ms	remaining: 2.17s
# 4:	learn: 0.8838074	total: 114ms	remaining: 2.17s
# 5:	learn: 0.8594070	total: 137ms	remaining: 2.15s
# 6:	learn: 0.8393376	total: 160ms	remaining: 2.13s
# 7:	learn: 0.8232058	total: 184ms	remaining: 2.12s
# 8:	learn: 0.8093535	total: 207ms	remaining: 2.09s
# 9:	learn: 0.7967328	total: 230ms	remaining: 2.06s
# 10:	learn: 0.7860365	total: 251ms	remaining: 2.03s
# 11:	learn: 0.7759482	total: 272ms	remaining: 1.99s
# 12:	learn: 0.7673640	total: 296ms	remaining: 1.98s
# 13:	learn: 0.7593845	total: 319ms	remaining: 1.96s
# 14:	learn: 0.7524052	total: 343ms	remaining: 1.94s
# 15:	learn: 0.7474416	total: 366ms	remaining: 1.92s
# 16:	learn: 0.7408613	total: 389ms	remaining: 1.9s
# 17:	learn: 0.7356376	total: 412ms	remaining: 1.88s
# 18:	learn: 0.7319611	total: 438ms	remaining: 1.87s
# 19:	learn: 0.7279315	total: 463ms	remaining: 1.85s
# 20:	learn: 0.7241411	total: 489ms	remaining: 1.84s
# 21:	learn: 0.7202578	total: 511ms	remaining: 1.81s
# 22:	learn: 0.7170067	total: 533ms	remaining: 1.78s
# 23:	learn: 0.7139059	total: 557ms	remaining: 1.76s
# 24:	learn: 0.7119887	total: 581ms	remaining: 1.74s
# 25:	learn: 0.7083645	total: 605ms	remaining: 1.72s
# 26:	learn: 0.7070285	total: 615ms	remaining: 1.66s
# 27:	learn: 0.7048629	total: 639ms	remaining: 1.64s
# 28:	learn: 0.7029253	total: 660ms	remaining: 1.61s
# 29:	learn: 0.6999152	total: 689ms	remaining: 1.61s
# 30:	learn: 0.6978036	total: 712ms	remaining: 1.58s
# 31:	learn: 0.6961623	total: 735ms	remaining: 1.56s
# 32:	learn: 0.6941585	total: 758ms	remaining: 1.54s
# 33:	learn: 0.6933232	total: 780ms	remaining: 1.51s
# 34:	learn: 0.6916952	total: 803ms	remaining: 1.49s
# 35:	learn: 0.6898541	total: 828ms	remaining: 1.47s
# 36:	learn: 0.6882272	total: 850ms	remaining: 1.45s
# 37:	learn: 0.6866373	total: 871ms	remaining: 1.42s
# 38:	learn: 0.6855225	total: 892ms	remaining: 1.39s
# 39:	learn: 0.6840680	total: 916ms	remaining: 1.37s
# 40:	learn: 0.6827559	total: 942ms	remaining: 1.35s
# 41:	learn: 0.6818573	total: 964ms	remaining: 1.33s
# 42:	learn: 0.6804186	total: 985ms	remaining: 1.3s
# 43:	learn: 0.6786000	total: 1.01s	remaining: 1.28s
# ...
# 45:	learn: 0.6103309	total: 37.8s	remaining: 3.28s
# 46:	learn: 0.6075780	total: 38.8s	remaining: 2.48s
# 47:	learn: 0.6061925	total: 39.7s	remaining: 1.66s
# 48:	learn: 0.6042849	total: 40.7s	remaining: 832ms
# 49:	learn: 0.6025050	total: 41.6s	remaining: 0us
# 0:	learn: 1.0347028	total: 1.06s	remaining: 51.9s
# 1:	learn: 0.9852061	total: 2.1s	remaining: 50.4s
# 2:	learn: 0.9443394	total: 3.09s	remaining: 48.4s
# 3:	learn: 0.9077990	total: 3.12s	remaining: 35.9s
# 4:	learn: 0.8783433	total: 4.1s	remaining: 36.9s
# 5:	learn: 0.8526055	total: 4.99s	remaining: 36.6s
# 6:	learn: 0.8326590	total: 5s	remaining: 30.7s
# 7:	learn: 0.8140123	total: 6.05s	remaining: 31.8s
# 8:	learn: 0.7974948	total: 7.09s	remaining: 32.3s
# 9:	learn: 0.7833108	total: 7.15s	remaining: 28.6s
# 10:	learn: 0.7692926	total: 8.19s	remaining: 29s
# 11:	learn: 0.7581968	total: 9.12s	remaining: 28.9s
# 12:	learn: 0.7468047	total: 10.2s	remaining: 29s
# 13:	learn: 0.7364879	total: 11.1s	remaining: 28.7s
# 14:	learn: 0.7267144	total: 12.2s	remaining: 28.4s
# 15:	learn: 0.7188871	total: 13.1s	remaining: 27.9s
# 16:	learn: 0.7118683	total: 14.1s	remaining: 27.4s
# 17:	learn: 0.7068276	total: 14.1s	remaining: 25.1s
# 18:	learn: 0.7017887	total: 15.1s	remaining: 24.7s
# 19:	learn: 0.6951113	total: 16s	remaining: 24s
# 20:	learn: 0.6888491	total: 17s	remaining: 23.5s
# 21:	learn: 0.6821478	total: 18s	remaining: 22.9s
# 22:	learn: 0.6763169	total: 18.9s	remaining: 22.2s
# 23:	learn: 0.6713675	total: 19.9s	remaining: 21.5s
# 24:	learn: 0.6669874	total: 20.7s	remaining: 20.7s
# 25:	learn: 0.6619525	total: 21.8s	remaining: 20.1s
# 26:	learn: 0.6580089	total: 22.7s	remaining: 19.3s
# 27:	learn: 0.6538617	total: 23.6s	remaining: 18.5s
# 28:	learn: 0.6506665	total: 24.5s	remaining: 17.8s
# 29:	learn: 0.6474690	total: 25.5s	remaining: 17s
# 30:	learn: 0.6443722	total: 26.6s	remaining: 16.3s
# 31:	learn: 0.6416020	total: 27.6s	remaining: 15.5s
# 32:	learn: 0.6397128	total: 28.6s	remaining: 14.7s
# 33:	learn: 0.6367638	total: 29.5s	remaining: 13.9s
# 34:	learn: 0.6341826	total: 30.5s	remaining: 13.1s
# 35:	learn: 0.6316593	total: 31.4s	remaining: 12.2s
# 36:	learn: 0.6284755	total: 32.3s	remaining: 11.3s
# 37:	learn: 0.6260834	total: 33.3s	remaining: 10.5s
# 38:	learn: 0.6244520	total: 34.2s	remaining: 9.64s
# 39:	learn: 0.6232487	total: 35.2s	remaining: 8.79s
# 40:	learn: 0.6204775	total: 36.2s	remaining: 7.95s
# 41:	learn: 0.6191495	total: 37.2s	remaining: 7.08s
# 42:	learn: 0.6170241	total: 38.1s	remaining: 6.2s
# 43:	learn: 0.6145563	total: 39s	remaining: 5.32s
# 44:	learn: 0.6116190	total: 40s	remaining: 4.45s
# 45:	learn: 0.6099983	total: 40.9s	remaining: 3.56s
# 46:	learn: 0.6076184	total: 41.9s	remaining: 2.68s
# 47:	learn: 0.6057251	total: 42.8s	remaining: 1.78s
# 48:	learn: 0.6042189	total: 43.6s	remaining: 890ms
# 49:	learn: 0.6030361	total: 44.5s	remaining: 0us
# 0:	learn: 1.0346841	total: 1.01s	remaining: 49.3s
# 1:	learn: 0.9828934	total: 1.04s	remaining: 24.9s
# 2:	learn: 0.9419294	total: 2.11s	remaining: 33.1s
# 3:	learn: 0.9086617	total: 2.12s	remaining: 24.4s
# 4:	learn: 0.8795211	total: 3.27s	remaining: 29.5s
# 5:	learn: 0.8554942	total: 3.29s	remaining: 24.1s
# 6:	learn: 0.8354553	total: 3.32s	remaining: 20.4s
# 7:	learn: 0.8192228	total: 3.33s	remaining: 17.5s
# 8:	learn: 0.8049966	total: 3.35s	remaining: 15.3s
# 9:	learn: 0.7882704	total: 4.48s	remaining: 17.9s
# 10:	learn: 0.7741750	total: 5.5s	remaining: 19.5s
# 11:	learn: 0.7607000	total: 6.49s	remaining: 20.5s
# 12:	learn: 0.7482579	total: 7.58s	remaining: 21.6s
# 13:	learn: 0.7371187	total: 8.54s	remaining: 22s
# 14:	learn: 0.7277812	total: 9.43s	remaining: 22s
# 15:	learn: 0.7185879	total: 10.3s	remaining: 22s
# 16:	learn: 0.7104301	total: 11.4s	remaining: 22.2s
# 17:	learn: 0.7032633	total: 12.3s	remaining: 21.9s
# 18:	learn: 0.6981629	total: 12.5s	remaining: 20.4s
# 19:	learn: 0.6948702	total: 12.5s	remaining: 18.7s
# 20:	learn: 0.6905345	total: 13.5s	remaining: 18.7s
# 21:	learn: 0.6845854	total: 14.6s	remaining: 18.5s
# 22:	learn: 0.6791561	total: 15.6s	remaining: 18.3s
# 23:	learn: 0.6735753	total: 16.6s	remaining: 17.9s
# 24:	learn: 0.6679832	total: 17.5s	remaining: 17.5s
# 25:	learn: 0.6631776	total: 18.5s	remaining: 17.1s
# 26:	learn: 0.6591275	total: 19.4s	remaining: 16.5s
# 27:	learn: 0.6549476	total: 20.5s	remaining: 16.1s
# 28:	learn: 0.6509055	total: 21.6s	remaining: 15.6s
# 29:	learn: 0.6469451	total: 22.6s	remaining: 15s
# 30:	learn: 0.6437506	total: 23.7s	remaining: 14.5s
# 31:	learn: 0.6405063	total: 24.8s	remaining: 13.9s
# 32:	learn: 0.6369400	total: 25.9s	remaining: 13.3s
# 33:	learn: 0.6340274	total: 26.9s	remaining: 12.6s
# 34:	learn: 0.6311955	total: 27.9s	remaining: 12s
# 35:	learn: 0.6273465	total: 28.9s	remaining: 11.2s
# 36:	learn: 0.6255624	total: 29.8s	remaining: 10.5s
# 37:	learn: 0.6235374	total: 30.8s	remaining: 9.71s
# 38:	learn: 0.6205752	total: 31.7s	remaining: 8.94s
# 39:	learn: 0.6175588	total: 32.6s	remaining: 8.14s
# 40:	learn: 0.6149274	total: 33.6s	remaining: 7.37s
# 41:	learn: 0.6125699	total: 34.5s	remaining: 6.58s
# 42:	learn: 0.6101909	total: 35.5s	remaining: 5.78s
# 43:	learn: 0.6083308	total: 36.5s	remaining: 4.98s
# 44:	learn: 0.6059972	total: 37.4s	remaining: 4.15s
# 45:	learn: 0.6041678	total: 38.5s	remaining: 3.35s
# 46:	learn: 0.6014958	total: 39.7s	remaining: 2.53s
# 47:	learn: 0.5998799	total: 40.6s	remaining: 1.69s
# 48:	learn: 0.5974999	total: 41.7s	remaining: 851ms
# 49:	learn: 0.5966655	total: 42.1s	remaining: 0us
# 0:	learn: 1.0344936	total: 1.11s	remaining: 54.4s
# 1:	learn: 0.9826671	total: 1.15s	remaining: 27.7s
# 2:	learn: 0.9417609	total: 2.57s	remaining: 40.2s
# 3:	learn: 0.9070063	total: 2.6s	remaining: 29.9s
# 4:	learn: 0.8781900	total: 3.51s	remaining: 31.6s
# 5:	learn: 0.8546500	total: 3.89s	remaining: 28.5s
# 6:	learn: 0.8332369	total: 4s	remaining: 24.5s
# 7:	learn: 0.8185268	total: 4s	remaining: 21s
# 8:	learn: 0.8001451	total: 4.96s	remaining: 22.6s
# 9:	learn: 0.7835855	total: 5.86s	remaining: 23.5s
# 10:	learn: 0.7687666	total: 6.86s	remaining: 24.3s
# 11:	learn: 0.7555806	total: 7.87s	remaining: 24.9s
# 12:	learn: 0.7447729	total: 8.79s	remaining: 25s
# 13:	learn: 0.7346643	total: 9.7s	remaining: 24.9s
# 14:	learn: 0.7273229	total: 10.8s	remaining: 25.2s
# 15:	learn: 0.7195558	total: 11.7s	remaining: 24.9s
# 16:	learn: 0.7126366	total: 12.7s	remaining: 24.7s
# 17:	learn: 0.7051464	total: 13.6s	remaining: 24.2s
# 18:	learn: 0.6993794	total: 14.7s	remaining: 24s
# 19:	learn: 0.6925238	total: 15.7s	remaining: 23.5s
# 20:	learn: 0.6873290	total: 16.6s	remaining: 22.9s
# 21:	learn: 0.6820386	total: 17.7s	remaining: 22.6s
# 22:	learn: 0.6772356	total: 18.8s	remaining: 22s
# 23:	learn: 0.6734874	total: 19.8s	remaining: 21.4s
# 24:	learn: 0.6684494	total: 20.7s	remaining: 20.7s
# 25:	learn: 0.6637814	total: 21.7s	remaining: 20s
# 26:	learn: 0.6595598	total: 22.6s	remaining: 19.2s
# 27:	learn: 0.6551256	total: 23.7s	remaining: 18.6s
# 28:	learn: 0.6517190	total: 24.1s	remaining: 17.4s
# 29:	learn: 0.6490006	total: 25.1s	remaining: 16.7s
# 30:	learn: 0.6455022	total: 26s	remaining: 15.9s
# 31:	learn: 0.6426321	total: 26.9s	remaining: 15.1s
# 32:	learn: 0.6391066	total: 27.8s	remaining: 14.3s
# 33:	learn: 0.6353897	total: 28.8s	remaining: 13.6s
# 34:	learn: 0.6329750	total: 29.7s	remaining: 12.7s
# 35:	learn: 0.6318784	total: 29.8s	remaining: 11.6s
# 36:	learn: 0.6292899	total: 30.7s	remaining: 10.8s
# 37:	learn: 0.6269170	total: 31.7s	remaining: 10s
# 38:	learn: 0.6240342	total: 32.8s	remaining: 9.25s
# 39:	learn: 0.6211685	total: 33.8s	remaining: 8.45s
# 40:	learn: 0.6207246	total: 33.8s	remaining: 7.42s
# 41:	learn: 0.6185749	total: 34.8s	remaining: 6.63s
# 42:	learn: 0.6164218	total: 35.9s	remaining: 5.84s
# 43:	learn: 0.6142433	total: 36.8s	remaining: 5.01s
# 44:	learn: 0.6119143	total: 37.8s	remaining: 4.19s
# 45:	learn: 0.6091105	total: 38.7s	remaining: 3.36s
# 46:	learn: 0.6080910	total: 38.7s	remaining: 2.47s
# 47:	learn: 0.6057892	total: 39.7s	remaining: 1.65s
# 48:	learn: 0.6043720	total: 40.5s	remaining: 826ms
# 49:	learn: 0.6024979	total: 41.4s	remaining: 0us
# 0:	learn: 1.0340331	total: 1.11s	remaining: 1m 50s
# 1:	learn: 0.9820199	total: 1.15s	remaining: 56.2s
# 2:	learn: 0.9400733	total: 2.21s	remaining: 1m 11s
# 3:	learn: 0.9044668	total: 3.08s	remaining: 1m 14s
# 4:	learn: 0.8744722	total: 4.18s	remaining: 1m 19s
# 5:	learn: 0.8490615	total: 5.16s	remaining: 1m 20s
# 6:	learn: 0.8287597	total: 5.17s	remaining: 1m 8s
# 7:	learn: 0.8097841	total: 6.12s	remaining: 1m 10s
# 8:	learn: 0.7930897	total: 7.15s	remaining: 1m 12s
# 9:	learn: 0.7797203	total: 8.23s	remaining: 1m 14s
# 10:	learn: 0.7667022	total: 9.19s	remaining: 1m 14s
# 11:	learn: 0.7544694	total: 10.2s	remaining: 1m 14s
# 12:	learn: 0.7445448	total: 11.2s	remaining: 1m 15s
# 13:	learn: 0.7352701	total: 12.3s	remaining: 1m 15s
# 14:	learn: 0.7251825	total: 13.4s	remaining: 1m 16s
# 15:	learn: 0.7167548	total: 14.4s	remaining: 1m 15s
# 16:	learn: 0.7090824	total: 15.4s	remaining: 1m 15s
# 17:	learn: 0.7052114	total: 15.4s	remaining: 1m 10s
# 18:	learn: 0.7000560	total: 16.6s	remaining: 1m 10s
# 19:	learn: 0.6935981	total: 17.6s	remaining: 1m 10s
# 20:	learn: 0.6885237	total: 18.5s	remaining: 1m 9s
# 21:	learn: 0.6823644	total: 19.6s	remaining: 1m 9s
# 22:	learn: 0.6765030	total: 20.7s	remaining: 1m 9s
# 23:	learn: 0.6717462	total: 21.7s	remaining: 1m 8s
# 24:	learn: 0.6680604	total: 22.8s	remaining: 1m 8s
# 25:	learn: 0.6637873	total: 23.9s	remaining: 1m 8s
# 26:	learn: 0.6601110	total: 25s	remaining: 1m 7s
# 27:	learn: 0.6554038	total: 26s	remaining: 1m 6s
# 28:	learn: 0.6505414	total: 27s	remaining: 1m 6s
# 29:	learn: 0.6473411	total: 28s	remaining: 1m 5s
# 30:	learn: 0.6436789	total: 29s	remaining: 1m 4s
# 31:	learn: 0.6403055	total: 30s	remaining: 1m 3s
# 32:	learn: 0.6373264	total: 31s	remaining: 1m 2s
# 33:	learn: 0.6332160	total: 31.9s	remaining: 1m 1s
# 34:	learn: 0.6304431	total: 33s	remaining: 1m 1s
# 35:	learn: 0.6281800	total: 34s	remaining: 1m
# 36:	learn: 0.6253861	total: 35.1s	remaining: 59.8s
# 37:	learn: 0.6230659	total: 36.2s	remaining: 59s
# 38:	learn: 0.6200542	total: 37.2s	remaining: 58.2s
# 39:	learn: 0.6168031	total: 38.2s	remaining: 57.4s
# 40:	learn: 0.6146591	total: 39.3s	remaining: 56.5s
# 41:	learn: 0.6128796	total: 40.3s	remaining: 55.7s
# 42:	learn: 0.6099128	total: 41.6s	remaining: 55.2s
# 43:	learn: 0.6082049	total: 42.7s	remaining: 54.3s
# 44:	learn: 0.6062719	total: 43.9s	remaining: 53.7s
# 45:	learn: 0.6049357	total: 45.1s	remaining: 53s
# 46:	learn: 0.6024274	total: 46.1s	remaining: 52s
# 47:	learn: 0.6017861	total: 46.1s	remaining: 50s
# 48:	learn: 0.5995258	total: 47.1s	remaining: 49s
# 49:	learn: 0.5992346	total: 47.1s	remaining: 47.1s
# 50:	learn: 0.5982243	total: 48.1s	remaining: 46.2s
# 51:	learn: 0.5963817	total: 49s	remaining: 45.2s
# 52:	learn: 0.5951971	total: 50s	remaining: 44.3s
# 53:	learn: 0.5943553	total: 50.9s	remaining: 43.4s
# 54:	learn: 0.5932643	total: 51.9s	remaining: 42.4s
# 55:	learn: 0.5926798	total: 53s	remaining: 41.6s
# 56:	learn: 0.5920959	total: 54s	remaining: 40.7s
# 57:	learn: 0.5908436	total: 55s	remaining: 39.8s
# 58:	learn: 0.5899814	total: 56.1s	remaining: 39s
# 59:	learn: 0.5886935	total: 57.2s	remaining: 38.2s
# 60:	learn: 0.5869712	total: 58.4s	remaining: 37.3s
# 61:	learn: 0.5856199	total: 59.5s	remaining: 36.5s
# 62:	learn: 0.5832644	total: 1m	remaining: 35.7s
# 63:	learn: 0.5825315	total: 1m	remaining: 34.2s
# 64:	learn: 0.5822785	total: 1m	remaining: 32.8s
# 65:	learn: 0.5807495	total: 1m 1s	remaining: 31.9s
# 66:	learn: 0.5804306	total: 1m 2s	remaining: 30.6s
# 67:	learn: 0.5795782	total: 1m 3s	remaining: 29.8s
# 68:	learn: 0.5789614	total: 1m 4s	remaining: 28.9s
# 69:	learn: 0.5788750	total: 1m 4s	remaining: 27.6s
# 70:	learn: 0.5769517	total: 1m 5s	remaining: 26.7s
# 71:	learn: 0.5754773	total: 1m 6s	remaining: 25.8s
# 72:	learn: 0.5737660	total: 1m 7s	remaining: 24.9s
# 73:	learn: 0.5727111	total: 1m 8s	remaining: 24s
# 74:	learn: 0.5714357	total: 1m 9s	remaining: 23.1s
# 75:	learn: 0.5695562	total: 1m 10s	remaining: 22.3s
# 76:	learn: 0.5676409	total: 1m 11s	remaining: 21.3s
# 77:	learn: 0.5656747	total: 1m 12s	remaining: 20.4s
# 78:	learn: 0.5648880	total: 1m 13s	remaining: 19.5s
# 79:	learn: 0.5646227	total: 1m 13s	remaining: 18.4s
# 80:	learn: 0.5630742	total: 1m 14s	remaining: 17.5s
# 81:	learn: 0.5618821	total: 1m 15s	remaining: 16.6s
# 82:	learn: 0.5607273	total: 1m 16s	remaining: 15.7s
# 83:	learn: 0.5591450	total: 1m 17s	remaining: 14.8s
# 84:	learn: 0.5578672	total: 1m 18s	remaining: 13.9s
# 85:	learn: 0.5565342	total: 1m 19s	remaining: 13s
# 86:	learn: 0.5554211	total: 1m 20s	remaining: 12.1s
# 87:	learn: 0.5538753	total: 1m 22s	remaining: 11.2s
# 88:	learn: 0.5530669	total: 1m 23s	remaining: 10.3s
# 89:	learn: 0.5521641	total: 1m 24s	remaining: 9.34s
# 90:	learn: 0.5504277	total: 1m 25s	remaining: 8.41s
# 91:	learn: 0.5481594	total: 1m 26s	remaining: 7.49s
# 92:	learn: 0.5470465	total: 1m 27s	remaining: 6.56s
# 93:	learn: 0.5459617	total: 1m 28s	remaining: 5.64s
# 94:	learn: 0.5444111	total: 1m 29s	remaining: 4.71s
# 95:	learn: 0.5432976	total: 1m 30s	remaining: 3.77s
# 96:	learn: 0.5421037	total: 1m 31s	remaining: 2.83s
# 97:	learn: 0.5409076	total: 1m 32s	remaining: 1.89s
# 98:	learn: 0.5398878	total: 1m 33s	remaining: 945ms
# 99:	learn: 0.5389129	total: 1m 34s	remaining: 0us
# Лучшие параметры: {'depth': 16, 'iterations': 100, 'learning_rate': 0.1}
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-1-c0e6e838daea> in <module>
#      23 # Оценка качества модели с лучшими параметрами на тестовой выборке
#      24 clf_best = CatBoostClassifier(**best_params, loss_function='MultiClass', eval_metric='MultiClassOneVsAll', random_seed=42)
# ---> 25 clf_best.fit(X_train, y_train)
#      26 y_pred = clf_best.predict(X_test)
#      27 roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr')
#
# /usr/local/lib/python3.8/dist-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    4192             self._check_is_classification_objective(params['loss_function'])
#    4193
# -> 4194         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4195                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
#    4196                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#
# /usr/local/lib/python3.8/dist-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1775             raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
#    1776
# -> 1777         train_params = self._prepare_train_params(
#    1778             X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id,
#    1779             group_weight, subgroup_id, pairs_weight, baseline,
#
# /usr/local/lib/python3.8/dist-packages/catboost/core.py in _prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1707         _check_param_types(params)
#    1708         params = _params_type_cast(params)
# -> 1709         _check_train_params(params)
#    1710
#    1711         eval_set_list = eval_set if isinstance(eval_set, list) else [eval_set]
#
# _catboost.pyx in _catboost._check_train_params()
#
# _catboost.pyx in _catboost._check_train_params()
#
# CatBoostError: catboost/private/libs/options/plain_options_helper.cpp:194: MultiClass and MultiClassOneVsAll are incompatible

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, max_depth=10)
clf.fit(X_train, y_train)

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = clf.predict_proba(X_test)
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print('ROC AUC score:', roc_auc)

# %%
y['sentiment'].unique()

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# Загружаем предварительно обученную модель BERT
model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased")

# Загружаем токенизатор
tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")

# Задаем текст для анализа
text = "Этот продукт действительно потрясающий! Я советую его всем!"

# Токенизируем текст и добавляем специальные токены
input_ids = torch.tensor([tokenizer.encode(text, add_special_tokens=True)])

# Передаем токенизированный текст в модель и получаем логиты
logits = model(input_ids)[0]

# Применяем функцию softmax к логитам и получаем вероятности для каждого класса
probs = torch.nn.functional.softmax(logits, dim=-1)

# Выбираем наиболее вероятный класс
pred_class = torch.argmax(probs, dim=-1).item()

# Выводим результат
if pred_class == 0:
    print("Отзыв отрицательный")
else:
    print("Отзыв положительный")
